# %% [markdown]
# # 7. Prediction PySpark
#
# Follow the following prediction example from the Agile Data Science 2.0 Book: <https://github.com/rjurney/Agile_Data_Code_2>
#
#
#
#
# # Initialize PySpark
#
# First, we use the findspark package to initialize PySpark.

# %%
# Initialize PySpark
SPARK_MASTER="local[1]"
#SPARK_MASTER="spark://mpp3r03c04s06.cos.lrz.de:7077"
APP_NAME = "PySpark Lecture"

# If there is no SparkSession, create the environment
try:
    sc and spark
except NameError as e:
  #import findspark
  #findspark.init()
    import pyspark
    import pyspark.sql
    sc = pyspark.SparkContext()
    spark = pyspark.sql.SparkSession(sc).builder.appName(APP_NAME).getOrCreate()

# %% [markdown]
# # Loading and Inspecting Parquet Files
#
# Using the `SparkSession` to load files as `DataFrames` and inspecting their contents...

# %%
# Load the parquet file containing flight delay records
on_time_dataframe = spark.read.parquet('../data/on_time_performance.parquet')

# Register the data for Spark SQL
on_time_dataframe.registerTempTable("on_time_performance")

# Check out the columns
on_time_dataframe.columns

# Check out some data
on_time_dataframe\
  .select("FlightDate", "TailNum", "Origin", "Dest", "Carrier", "DepDelay", "ArrDelay")\
  .show()

# Trim the fields and keep the result
trimmed_on_time = on_time_dataframe\
  .select(
    "FlightDate",
    "TailNum",
    "Origin",
    "Dest",
    "Carrier",
    "DepDelay",
    "ArrDelay"
  )

# Sample 0.01% of the data and show
trimmed_on_time.sample(False, 0.0001).show()
# Out:
# +----------+-------+------+----+-------+--------+--------+
# |FlightDate|TailNum|Origin|Dest|Carrier|DepDelay|ArrDelay|
# +----------+-------+------+----+-------+--------+--------+
# |2015-01-01| N001AA|   DFW| MEM|     AA|    -3.0|    -6.0|
# |2015-01-01| N001AA|   MEM| DFW|     AA|    -4.0|    -9.0|
# |2015-01-01| N002AA|   ORD| DFW|     AA|     0.0|    26.0|
# |2015-01-01| N003AA|   DFW| ATL|     AA|   100.0|   112.0|
# |2015-01-01| N003AA|   DFW| HDN|     AA|    78.0|    78.0|
# |2015-01-01| N003AA|   HDN| DFW|     AA|   332.0|   336.0|
# |2015-01-01| N004AA|   JAC| DFW|     AA|    -4.0|    21.0|
# |2015-01-01| N005AA|   EGE| ORD|     AA|    null|    null|
# |2015-01-01| N005AA|   ORD| EGE|     AA|    null|    null|
# |2015-01-01| N005AA|   DFW| ORD|     AA|    null|    null|
# |2015-01-01| N006AA|   DFW| ATL|     AA|    null|    null|
# |2015-01-01| N006AA|   ATL| DFW|     AA|    -5.0|     1.0|
# |2015-01-01| N006AA|   DFW| ATL|     AA|    -4.0|   -11.0|
# |2015-01-01| N007AA|   DFW| ATL|     AA|    76.0|    86.0|
# |2015-01-01| N008AA|   ATL| DFW|     AA|    -2.0|    -7.0|
# |2015-01-01| N008AA|   DFW| ATL|     AA|    -5.0|   -25.0|
# |2015-01-01| N009AA|   DFW| EGE|     AA|    35.0|    17.0|
# |2015-01-01| N009AA|   EGE| LAX|     AA|    10.0|   -12.0|
# |2015-01-01| N010AA|   DFW| SDF|     AA|    null|    null|
# |2015-01-01| N010AA|   SDF| DFW|     AA|    null|    null|
# +----------+-------+------+----+-------+--------+--------+
# only showing top 20 rows
#
# +----------+-------+------+----+-------+--------+--------+
# |FlightDate|TailNum|Origin|Dest|Carrier|DepDelay|ArrDelay|
# +----------+-------+------+----+-------+--------+--------+
# |2015-01-01| N970SW|   BIL| DEN|     OO|   -12.0|   -18.0|
# |2015-01-10| N659DL|   MSP| DEN|     DL|    -3.0|    -8.0|
# |2015-01-10| N923MQ|   BTR| DFW|     MQ|     4.0|    13.0|
# |2015-01-10| N505UA|   JFK| SFO|     UA|    -4.0|   -32.0|
# |2015-01-10| N8614M|   BWI| ALB|     WN|    -4.0|    -6.0|
# |2015-01-12| N305DQ|   EYW| ATL|     DL|   948.0|   956.0|
# |2015-01-12| N449WN|   DCA| MKE|     WN|    -3.0|   -10.0|
# |2015-01-13| N12530|   DAL| IAH|     EV|    -1.0|     1.0|
# |2015-01-13| N751EV|   LGA| GSO|     EV|    -8.0|   -10.0|
# |2015-01-13| N508MQ|   STL| LGA|     MQ|    20.0|    16.0|
# |2015-01-13| N265WN|   BNA| MDW|     WN|    -7.0|   -12.0|
# |2015-01-13| N708SW|   DEN| MCI|     WN|    -4.0|    -7.0|
# |2015-01-14| N3JRAA|   CLT| DFW|     AA|    -3.0|    -2.0|
# |2015-01-14| N23708|   LAS| EWR|     UA|    -7.0|   -21.0|
# |2015-01-14| N538UW|   BOS| CLT|     US|    -4.0|   -12.0|
# |2015-01-15| N025AA|   MIA| IAD|     AA|    22.0|    19.0|
# |2015-01-15| N962DL|   ATL| MOB|     DL|     2.0|    -2.0|
# |2015-01-16| N421UA|   LAX| LAS|     UA|    20.0|    15.0|
# |2015-01-18| N53442|   ORD| IAH|     UA|     4.0|   -18.0|
# |2015-01-18| N469WN|   DEN| TUS|     WN|    -6.0|   -20.0|
# +----------+-------+------+----+-------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# # Calculating Histograms
#
# Using `RDDs` to calculate histograms buckets and values...

# %%
# Compute a histogram of departure delays
on_time_dataframe\
  .select("DepDelay")\
  .rdd\
  .flatMap(lambda x: x)\
  .histogram(10)
# Out:
# ([-82.0,
#   125.0,
#   332.0,
#   539.0,
#   746.0,
#   953.0,
#   1160.0,
#   1367.0,
#   1574.0,
#   1781.0,
#   1988.0],
#  [5623798, 100893, 6404, 1013, 486, 211, 76, 34, 9, 2])

# %% [markdown]
# # Visualizing Histograms
#
# Using pyplot to visualize histograms...

# %%
# %matplotlib inline

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# Function to plot a histogram using pyplot
def create_hist(rdd_histogram_data):
    """Given an RDD.histogram, plot a pyplot histogram"""
    heights = np.array(rdd_histogram_data[1])
    full_bins = rdd_histogram_data[0]
    mid_point_bins = full_bins[:-1]
    widths = [abs(i - j) for i, j in zip(full_bins[:-1], full_bins[1:])]
    bar = plt.bar(mid_point_bins, heights, width=widths, color='b')
    return bar

# Compute a histogram of departure delays
departure_delay_histogram = on_time_dataframe\
  .select("DepDelay")\
  .rdd\
  .flatMap(lambda x: x)\
  .histogram([-60,-30,-15,-10,-5,0,5,10,15,30,60,90,120,180])

create_hist(departure_delay_histogram)
# Out:
# /home/hpc/ug201/di57hah/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# <Container object of 13 artists>

# %% [markdown]
# # Counting Airplanes in the US Fleet

# %%
# Dump the unneeded fields
tail_numbers = on_time_dataframe.rdd.map(lambda x: x.TailNum)
tail_numbers = tail_numbers.filter(lambda x: x != '')

# distinct() gets us unique tail numbers
unique_tail_numbers = tail_numbers.distinct()

# now we need a count() of unique tail numbers
airplane_count = unique_tail_numbers.count()
print("Total airplanes: {}".format(airplane_count))
# Out:
# Total airplanes: 4898

# %% [markdown]
# # Counting the Total Flights Per Month

# %%
# Use SQL to look at the total flights by month across 2015
on_time_dataframe.registerTempTable("on_time_dataframe")
total_flights_by_month = spark.sql(
  """SELECT Month, Year, COUNT(*) AS total_flights
  FROM on_time_dataframe
  GROUP BY Year, Month
  ORDER BY Year, Month"""
)

# This map/asDict trick makes the rows print a little prettier. It is optional.
flights_chart_data = total_flights_by_month.rdd.map(lambda row: row.asDict())
flights_chart_data.collect()
# Out:
# [{'Month': u'1', 'Year': u'2015', 'total_flights': 469968},
#  {'Month': u'10', 'Year': u'2015', 'total_flights': 486165},
#  {'Month': u'11', 'Year': u'2015', 'total_flights': 467972},
#  {'Month': u'12', 'Year': u'2015', 'total_flights': 479230},
#  {'Month': u'2', 'Year': u'2015', 'total_flights': 429191},
#  {'Month': u'3', 'Year': u'2015', 'total_flights': 504312},
#  {'Month': u'4', 'Year': u'2015', 'total_flights': 485151},
#  {'Month': u'5', 'Year': u'2015', 'total_flights': 496993},
#  {'Month': u'6', 'Year': u'2015', 'total_flights': 503897},
#  {'Month': u'7', 'Year': u'2015', 'total_flights': 520718},
#  {'Month': u'8', 'Year': u'2015', 'total_flights': 510536},
#  {'Month': u'9', 'Year': u'2015', 'total_flights': 464946}]

# %% [markdown]
# # Using RDDs and Map/Reduce to Prepare a Complex Record

# %%
# Filter down to the fields we need to identify and link to a flight
flights = on_time_dataframe.rdd.map(lambda x: 
  (x.Carrier, x.FlightDate, x.FlightNum, x.Origin, x.Dest, x.TailNum)
  )

# Group flights by tail number, sorted by date, then flight number, then origin/dest
flights_per_airplane = flights\
  .map(lambda nameTuple: (nameTuple[5], [nameTuple[0:5]]))\
  .reduceByKey(lambda a, b: a + b)\
  .map(lambda tuple:
      {
        'TailNum': tuple[0], 
        'Flights': sorted(tuple[1], key=lambda x: (x[1], x[2], x[3], x[4]))
      }
    )
flights_per_airplane.first()
# Out:
# {'Flights': [(u'US', u'2015-01-01', u'1726', u'EWR', u'CLT'),
#   (u'US', u'2015-01-01', u'873', u'CLT', u'ATL'),
#   (u'US', u'2015-01-01', u'889', u'ATL', u'CLT'),
#   (u'US', u'2015-01-02', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-01-02', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-01-02', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-01-03', u'821', u'MSY', u'CLT'),
#   (u'US', u'2015-01-04', u'1700', u'CLT', u'FLL'),
#   (u'US', u'2015-01-04', u'1816', u'PHL', u'PIT'),
#   (u'US', u'2015-01-04', u'1866', u'FLL', u'CLT'),
#   (u'US', u'2015-01-04', u'820', u'CLT', u'PHL'),
#   (u'US', u'2015-01-05', u'1896', u'PHL', u'DEN'),
#   (u'US', u'2015-01-05', u'1896', u'PIT', u'PHL'),
#   (u'US', u'2015-01-05', u'492', u'DEN', u'PHL'),
#   (u'US', u'2015-01-05', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-01-06', u'1746', u'DFW', u'PHL'),
#   (u'US', u'2015-01-06', u'1790', u'FLL', u'PHL'),
#   (u'US', u'2015-01-06', u'2001', u'PHL', u'FLL'),
#   (u'US', u'2015-01-07', u'1705', u'PHL', u'PIT'),
#   (u'US', u'2015-01-07', u'1705', u'PIT', u'PHL'),
#   (u'US', u'2015-01-07', u'1824', u'PBI', u'PHL'),
#   (u'US', u'2015-01-07', u'1824', u'PHL', u'PBI'),
#   (u'US', u'2015-01-07', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-01-08', u'1746', u'DFW', u'PHL'),
#   (u'US', u'2015-01-08', u'1746', u'PHL', u'MCO'),
#   (u'US', u'2015-01-08', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-01-08', u'794', u'MCO', u'PHL'),
#   (u'US', u'2015-01-09', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-01-09', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-01-09', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-01-10', u'1829', u'RSW', u'CLT'),
#   (u'US', u'2015-01-10', u'2018', u'CLT', u'RSW'),
#   (u'US', u'2015-01-10', u'853', u'CLT', u'BUF'),
#   (u'US', u'2015-01-11', u'1707', u'BUF', u'CLT'),
#   (u'US', u'2015-01-11', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-01-12', u'821', u'DTW', u'CLT'),
#   (u'US', u'2015-01-13', u'1790', u'FLL', u'PHL'),
#   (u'US', u'2015-01-13', u'1932', u'CLT', u'PHL'),
#   (u'US', u'2015-01-13', u'2001', u'PHL', u'FLL'),
#   (u'US', u'2015-01-13', u'703', u'PHL', u'MIA'),
#   (u'US', u'2015-01-13', u'792', u'MIA', u'PHL'),
#   (u'US', u'2015-01-14', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-01-14', u'1774', u'PBI', u'CLT'),
#   (u'US', u'2015-01-14', u'1850', u'MCO', u'PHL'),
#   (u'US', u'2015-01-14', u'1850', u'PHL', u'MCO'),
#   (u'US', u'2015-01-14', u'1875', u'CLT', u'PBI'),
#   (u'US', u'2015-01-14', u'1875', u'PHL', u'CLT'),
#   (u'US', u'2015-01-15', u'821', u'DTW', u'CLT'),
#   (u'US', u'2015-01-16', u'1935', u'PHL', u'PBI'),
#   (u'US', u'2015-01-16', u'401', u'CLT', u'PHL'),
#   (u'US', u'2015-01-16', u'543', u'PHL', u'DFW'),
#   (u'US', u'2015-01-16', u'750', u'DFW', u'PHL'),
#   (u'US', u'2015-01-17', u'824', u'PBI', u'PHL'),
#   (u'US', u'2015-01-18', u'543', u'PHL', u'DFW'),
#   (u'US', u'2015-01-18', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-01-18', u'750', u'DFW', u'PHL'),
#   (u'US', u'2015-01-19', u'2022', u'FLL', u'PHL'),
#   (u'US', u'2015-01-19', u'2022', u'PHL', u'FLL'),
#   (u'US', u'2015-01-19', u'580', u'SLC', u'PHL'),
#   (u'US', u'2015-01-20', u'1727', u'LAS', u'PHL'),
#   (u'US', u'2015-01-20', u'1727', u'PHL', u'LAS'),
#   (u'US', u'2015-01-21', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-01-21', u'1774', u'PBI', u'CLT'),
#   (u'US', u'2015-01-21', u'1850', u'MCO', u'PHL'),
#   (u'US', u'2015-01-21', u'1850', u'PHL', u'MCO'),
#   (u'US', u'2015-01-21', u'1875', u'CLT', u'PBI'),
#   (u'US', u'2015-01-21', u'1875', u'PHL', u'CLT'),
#   (u'US', u'2015-01-22', u'1861', u'CLT', u'RDU'),
#   (u'US', u'2015-01-22', u'821', u'DTW', u'CLT'),
#   (u'US', u'2015-01-23', u'1790', u'FLL', u'PHL'),
#   (u'US', u'2015-01-23', u'1901', u'RDU', u'CLT'),
#   (u'US', u'2015-01-23', u'1932', u'CLT', u'PHL'),
#   (u'US', u'2015-01-23', u'2001', u'PHL', u'FLL'),
#   (u'US', u'2015-01-23', u'2022', u'FLL', u'PHL'),
#   (u'US', u'2015-01-23', u'2022', u'PHL', u'FLL'),
#   (u'US', u'2015-01-25', u'1971', u'CLT', u'SYR'),
#   (u'US', u'2015-01-25', u'1971', u'ORD', u'CLT'),
#   (u'US', u'2015-01-25', u'743', u'PHL', u'ORD'),
#   (u'US', u'2015-01-26', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-01-26', u'2053', u'SYR', u'CLT'),
#   (u'US', u'2015-01-27', u'1821', u'CLT', u'DTW'),
#   (u'US', u'2015-01-27', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-01-27', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-01-27', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-01-28', u'1806', u'ORD', u'CLT'),
#   (u'US', u'2015-01-28', u'1862', u'CLT', u'ORD'),
#   (u'US', u'2015-01-28', u'674', u'CLT', u'CHS'),
#   (u'US', u'2015-01-28', u'821', u'DTW', u'CLT'),
#   (u'US', u'2015-01-29', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-01-29', u'865', u'CHS', u'CLT'),
#   (u'US', u'2015-01-30', u'674', u'CLT', u'CHS'),
#   (u'US', u'2015-01-30', u'879', u'MIA', u'CLT'),
#   (u'US', u'2015-01-31', u'1740', u'CLT', u'LGA'),
#   (u'US', u'2015-01-31', u'2006', u'CHS', u'CLT'),
#   (u'US', u'2015-02-01', u'2069', u'CLT', u'IAH'),
#   (u'US', u'2015-02-01', u'2069', u'LGA', u'CLT'),
#   (u'US', u'2015-02-02', u'1707', u'IAH', u'CLT'),
#   (u'US', u'2015-02-02', u'674', u'CLT', u'CHS'),
#   (u'US', u'2015-02-03', u'865', u'CHS', u'CLT'),
#   (u'US', u'2015-02-04', u'401', u'CLT', u'PHL'),
#   (u'US', u'2015-02-04', u'543', u'PHL', u'DFW'),
#   (u'US', u'2015-02-04', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-02-04', u'750', u'DFW', u'PHL'),
#   (u'US', u'2015-02-05', u'2022', u'FLL', u'PHL'),
#   (u'US', u'2015-02-05', u'2022', u'PHL', u'FLL'),
#   (u'US', u'2015-02-05', u'580', u'SLC', u'PHL'),
#   (u'US', u'2015-02-08', u'1971', u'CLT', u'SYR'),
#   (u'US', u'2015-02-08', u'1971', u'ORD', u'CLT'),
#   (u'US', u'2015-02-08', u'743', u'PHL', u'ORD'),
#   (u'US', u'2015-02-09', u'1935', u'PHL', u'PBI'),
#   (u'US', u'2015-02-09', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-02-09', u'2053', u'SYR', u'CLT'),
#   (u'US', u'2015-02-09', u'2053', u'TPA', u'PHL'),
#   (u'US', u'2015-02-10', u'1821', u'CLT', u'DTW'),
#   (u'US', u'2015-02-10', u'1835', u'PBI', u'PHL'),
#   (u'US', u'2015-02-10', u'1835', u'PHL', u'TPA'),
#   (u'US', u'2015-02-10', u'2036', u'TPA', u'CLT'),
#   (u'US', u'2015-02-11', u'1815', u'CLT', u'PIT'),
#   (u'US', u'2015-02-11', u'1864', u'PIT', u'CLT'),
#   (u'US', u'2015-02-11', u'821', u'DTW', u'CLT'),
#   (u'US', u'2015-02-12', u'1770', u'SLC', u'PHL'),
#   (u'US', u'2015-02-12', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-02-13', u'1935', u'PHL', u'PBI'),
#   (u'US', u'2015-02-14', u'1714', u'PHL', u'ORD'),
#   (u'US', u'2015-02-14', u'2010', u'PBI', u'PHL'),
#   (u'US', u'2015-02-15', u'558', u'PHL', u'BOS'),
#   (u'US', u'2015-02-15', u'668', u'ORD', u'PHL'),
#   (u'US', u'2015-02-16', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-02-16', u'739', u'BOS', u'PHL'),
#   (u'US', u'2015-02-17', u'1887', u'DFW', u'PHL'),
#   (u'US', u'2015-02-17', u'1887', u'PHL', u'FLL'),
#   (u'US', u'2015-02-17', u'1888', u'FLL', u'PHL'),
#   (u'US', u'2015-02-17', u'1888', u'PHL', u'BOS'),
#   (u'US', u'2015-02-18', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-02-18', u'739', u'BOS', u'PHL'),
#   (u'US', u'2015-02-19', u'1887', u'DFW', u'PHL'),
#   (u'US', u'2015-02-19', u'1887', u'PHL', u'FLL'),
#   (u'US', u'2015-02-19', u'1888', u'FLL', u'PHL'),
#   (u'US', u'2015-02-19', u'1888', u'PHL', u'BOS'),
#   (u'US', u'2015-02-20', u'581', u'PHL', u'SAN'),
#   (u'US', u'2015-02-20', u'581', u'SAN', u'PHL'),
#   (u'US', u'2015-02-20', u'739', u'BOS', u'PHL'),
#   (u'US', u'2015-02-21', u'1748', u'PHL', u'MCO'),
#   (u'US', u'2015-02-22', u'1810', u'CLT', u'TPA'),
#   (u'US', u'2015-02-22', u'1810', u'TPA', u'CLT'),
#   (u'US', u'2015-02-22', u'856', u'TPA', u'CLT'),
#   (u'US', u'2015-02-23', u'1769', u'PBI', u'CLT'),
#   (u'US', u'2015-02-23', u'1789', u'CLT', u'PBI'),
#   (u'US', u'2015-02-23', u'1789', u'ORD', u'CLT'),
#   (u'US', u'2015-02-23', u'1976', u'CLT', u'EWR'),
#   (u'US', u'2015-02-23', u'1989', u'CLT', u'ORD'),
#   (u'US', u'2015-02-24', u'1829', u'ATL', u'CLT'),
#   (u'US', u'2015-02-24', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-02-24', u'2042', u'CLT', u'JFK'),
#   (u'US', u'2015-02-24', u'469', u'EWR', u'CLT'),
#   (u'US', u'2015-02-24', u'873', u'CLT', u'ATL'),
#   (u'US', u'2015-02-24', u'873', u'JFK', u'CLT'),
#   (u'US', u'2015-02-25', u'1976', u'CLT', u'EWR'),
#   (u'US', u'2015-02-25', u'2045', u'IAH', u'CLT'),
#   (u'US', u'2015-02-25', u'2061', u'CLT', u'IAH'),
#   (u'US', u'2015-02-25', u'2061', u'TPA', u'CLT'),
#   (u'US', u'2015-02-25', u'2063', u'CLT', u'BWI'),
#   (u'US', u'2015-02-25', u'856', u'BWI', u'CLT'),
#   (u'US', u'2015-02-26', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-02-26', u'1976', u'IAH', u'CLT'),
#   (u'US', u'2015-02-26', u'469', u'EWR', u'CLT'),
#   (u'US', u'2015-02-26', u'657', u'CLT', u'IAH'),
#   (u'US', u'2015-02-27', u'2011', u'PBI', u'PHL'),
#   (u'US', u'2015-02-27', u'2011', u'PHL', u'PBI'),
#   (u'US', u'2015-02-27', u'2013', u'CLT', u'RDU'),
#   (u'US', u'2015-02-27', u'2013', u'PIT', u'CLT'),
#   (u'US', u'2015-02-27', u'744', u'CLT', u'PHL'),
#   (u'US', u'2015-02-27', u'744', u'RDU', u'CLT'),
#   (u'US', u'2015-03-01', u'1770', u'SLC', u'PHL'),
#   (u'US', u'2015-03-01', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-03-02', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-03-03', u'1829', u'ATL', u'CLT'),
#   (u'US', u'2015-03-03', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-03-03', u'2042', u'CLT', u'JFK'),
#   (u'US', u'2015-03-03', u'2061', u'TPA', u'CLT'),
#   (u'US', u'2015-03-03', u'873', u'CLT', u'ATL'),
#   (u'US', u'2015-03-03', u'873', u'JFK', u'CLT'),
#   (u'US', u'2015-03-04', u'1760', u'CLT', u'FLL'),
#   (u'US', u'2015-03-04', u'1760', u'PHL', u'CLT'),
#   (u'US', u'2015-03-04', u'1760', u'TPA', u'PHL'),
#   (u'US', u'2015-03-04', u'1861', u'CLT', u'RDU'),
#   (u'US', u'2015-03-04', u'1861', u'FLL', u'CLT'),
#   (u'US', u'2015-03-05', u'1901', u'CLT', u'PBI'),
#   (u'US', u'2015-03-05', u'1901', u'RDU', u'CLT'),
#   (u'US', u'2015-03-05', u'2066', u'PBI', u'CLT'),
#   (u'US', u'2015-03-06', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-03-06', u'1747', u'MSY', u'CLT'),
#   (u'US', u'2015-03-06', u'2045', u'CLT', u'MSY'),
#   (u'US', u'2015-03-06', u'2045', u'IAH', u'CLT'),
#   (u'US', u'2015-03-06', u'2061', u'CLT', u'IAH'),
#   (u'US', u'2015-03-07', u'739', u'PIT', u'PHL'),
#   (u'US', u'2015-03-08', u'2011', u'PBI', u'PHL'),
#   (u'US', u'2015-03-08', u'2011', u'PHL', u'PBI'),
#   (u'US', u'2015-03-09', u'1850', u'MCO', u'PHL'),
#   (u'US', u'2015-03-09', u'1850', u'PHL', u'MCO'),
#   (u'US', u'2015-03-09', u'729', u'PHL', u'SEA'),
#   (u'US', u'2015-03-10', u'2022', u'FLL', u'PHL'),
#   (u'US', u'2015-03-10', u'2022', u'PHL', u'FLL'),
#   (u'US', u'2015-03-10', u'588', u'SEA', u'PHL'),
#   (u'US', u'2015-03-11', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-03-11', u'678', u'SJU', u'PHL'),
#   (u'US', u'2015-03-11', u'770', u'PHL', u'SJU'),
#   (u'US', u'2015-03-12', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-03-12', u'1919', u'JFK', u'CLT'),
#   (u'US', u'2015-03-12', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-03-12', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-03-12', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-03-12', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-03-13', u'2053', u'MIA', u'CLT'),
#   (u'US', u'2015-03-13', u'753', u'CLT', u'PHX'),
#   (u'US', u'2015-03-14', u'1782', u'CLT', u'EWR'),
#   (u'US', u'2015-03-14', u'2074', u'PHX', u'CLT'),
#   (u'US', u'2015-03-15', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-03-15', u'1774', u'PVD', u'CLT'),
#   (u'US', u'2015-03-15', u'1864', u'CLT', u'PVD'),
#   (u'US', u'2015-03-15', u'1864', u'IAH', u'CLT'),
#   (u'US', u'2015-03-15', u'1978', u'CLT', u'IAH'),
#   (u'US', u'2015-03-15', u'1978', u'EWR', u'CLT'),
#   (u'US', u'2015-03-16', u'2005', u'CLT', u'FLL'),
#   (u'US', u'2015-03-16', u'2005', u'IAH', u'CLT'),
#   (u'US', u'2015-03-16', u'2065', u'CLT', u'IAH'),
#   (u'US', u'2015-03-16', u'2065', u'DTW', u'CLT'),
#   (u'US', u'2015-03-17', u'1873', u'BWI', u'CLT'),
#   (u'US', u'2015-03-17', u'1873', u'CLT', u'TPA'),
#   (u'US', u'2015-03-17', u'1962', u'CLT', u'BWI'),
#   (u'US', u'2015-03-17', u'1962', u'MSP', u'CLT'),
#   (u'US', u'2015-03-17', u'713', u'CLT', u'MSP'),
#   (u'US', u'2015-03-17', u'713', u'FLL', u'CLT'),
#   (u'US', u'2015-03-18', u'2005', u'CLT', u'FLL'),
#   (u'US', u'2015-03-18', u'2005', u'IAH', u'CLT'),
#   (u'US', u'2015-03-18', u'2061', u'TPA', u'CLT'),
#   (u'US', u'2015-03-18', u'2065', u'CLT', u'IAH'),
#   (u'US', u'2015-03-18', u'469', u'CLT', u'ATL'),
#   (u'US', u'2015-03-18', u'657', u'ATL', u'CLT'),
#   (u'US', u'2015-03-19', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-03-19', u'1873', u'BWI', u'CLT'),
#   (u'US', u'2015-03-19', u'1962', u'CLT', u'BWI'),
#   (u'US', u'2015-03-19', u'1962', u'MSP', u'CLT'),
#   (u'US', u'2015-03-19', u'713', u'CLT', u'MSP'),
#   (u'US', u'2015-03-19', u'713', u'FLL', u'CLT'),
#   (u'US', u'2015-03-20', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-03-20', u'2065', u'DTW', u'CLT'),
#   (u'US', u'2015-03-21', u'1717', u'CLT', u'FLL'),
#   (u'US', u'2015-03-21', u'879', u'MIA', u'CLT'),
#   (u'US', u'2015-03-22', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-03-22', u'658', u'CLT', u'LAS'),
#   (u'US', u'2015-03-22', u'658', u'FLL', u'CLT'),
#   (u'US', u'2015-03-22', u'734', u'LAS', u'PHL'),
#   (u'US', u'2015-03-23', u'1887', u'DFW', u'PHL'),
#   (u'US', u'2015-03-23', u'1887', u'PHL', u'FLL'),
#   (u'US', u'2015-03-23', u'1888', u'FLL', u'PHL'),
#   (u'US', u'2015-03-23', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-03-24', u'1887', u'DFW', u'PHL'),
#   (u'US', u'2015-03-24', u'1887', u'PHL', u'FLL'),
#   (u'US', u'2015-03-24', u'1888', u'FLL', u'PHL'),
#   (u'US', u'2015-03-24', u'1888', u'PHL', u'BOS'),
#   (u'US', u'2015-03-25', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-03-25', u'739', u'BOS', u'PHL'),
#   (u'US', u'2015-03-26', u'1887', u'DFW', u'PHL'),
#   (u'US', u'2015-03-27', u'2011', u'PBI', u'PHL'),
#   (u'US', u'2015-03-27', u'2011', u'PHL', u'PBI'),
#   (u'US', u'2015-03-28', u'1925', u'PHL', u'CLT'),
#   (u'US', u'2015-03-28', u'2005', u'CLT', u'FLL'),
#   (u'US', u'2015-03-29', u'658', u'CLT', u'LAS'),
#   (u'US', u'2015-03-29', u'658', u'FLL', u'CLT'),
#   (u'US', u'2015-03-29', u'734', u'LAS', u'PHL'),
#   (u'US', u'2015-03-30', u'1782', u'CLT', u'EWR'),
#   (u'US', u'2015-03-30', u'1866', u'CLT', u'PBI'),
#   (u'US', u'2015-03-30', u'1866', u'PHL', u'CLT'),
#   (u'US', u'2015-03-30', u'1972', u'CLT', u'EWR'),
#   (u'US', u'2015-03-30', u'1972', u'PBI', u'CLT'),
#   (u'US', u'2015-03-30', u'423', u'EWR', u'CLT'),
#   (u'US', u'2015-03-31', u'1760', u'BOS', u'CLT'),
#   (u'US', u'2015-03-31', u'1901', u'EWR', u'CLT'),
#   (u'US', u'2015-03-31', u'1916', u'CLT', u'DCA'),
#   (u'US', u'2015-03-31', u'1980', u'CLT', u'BOS'),
#   (u'US', u'2015-04-01', u'1753', u'CLT', u'JAX'),
#   (u'US', u'2015-04-01', u'1916', u'CLT', u'DCA'),
#   (u'US', u'2015-04-01', u'1916', u'SYR', u'CLT'),
#   (u'US', u'2015-04-01', u'1988', u'DCA', u'CLT'),
#   (u'US', u'2015-04-01', u'2036', u'CLT', u'SYR'),
#   (u'US', u'2015-04-01', u'2036', u'JAX', u'CLT'),
#   (u'US', u'2015-04-02', u'1782', u'CLT', u'EWR'),
#   (u'US', u'2015-04-02', u'1782', u'IAH', u'CLT'),
#   (u'US', u'2015-04-02', u'1830', u'CLT', u'JFK'),
#   (u'US', u'2015-04-02', u'1830', u'DCA', u'CLT'),
#   (u'US', u'2015-04-02', u'2069', u'CLT', u'IAH'),
#   (u'US', u'2015-04-02', u'2069', u'JFK', u'CLT'),
#   (u'US', u'2015-04-03', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-04-03', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-04-03', u'1901', u'CLT', u'PBI'),
#   (u'US', u'2015-04-03', u'1901', u'EWR', u'CLT'),
#   (u'US', u'2015-04-03', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-04-03', u'2066', u'PBI', u'CLT'),
#   (u'US', u'2015-04-04', u'1740', u'CLT', u'LGA'),
#   (u'US', u'2015-04-04', u'858', u'MSY', u'CLT'),
#   (u'US', u'2015-04-05', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-04-05', u'1829', u'TPA', u'PHX'),
#   (u'US', u'2015-04-05', u'1956', u'LGA', u'CLT'),
#   (u'US', u'2015-04-05', u'2079', u'PHX', u'TPA'),
#   (u'US', u'2015-04-06', u'1795', u'DFW', u'PHL'),
#   (u'US', u'2015-04-06', u'1848', u'PHL', u'DFW'),
#   (u'US', u'2015-04-06', u'1848', u'TPA', u'PHL'),
#   (u'US', u'2015-04-06', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-04-07', u'1769', u'CLT', u'MCI'),
#   (u'US', u'2015-04-07', u'1789', u'DFW', u'PHL'),
#   (u'US', u'2015-04-07', u'1789', u'PHL', u'CLT'),
#   (u'US', u'2015-04-07', u'1919', u'JFK', u'CLT'),
#   (u'US', u'2015-04-07', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-04-08', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-04-08', u'1944', u'MCI', u'CLT'),
#   (u'US', u'2015-04-08', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-04-08', u'2053', u'TPA', u'PHL'),
#   (u'US', u'2015-04-09', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-04-09', u'1919', u'JFK', u'CLT'),
#   (u'US', u'2015-04-09', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-04-09', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-04-09', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-04-09', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-04-10', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-04-10', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-04-10', u'2053', u'MIA', u'CLT'),
#   (u'US', u'2015-04-10', u'2053', u'TPA', u'PHL'),
#   (u'US', u'2015-04-11', u'1962', u'TPA', u'PHL'),
#   (u'US', u'2015-04-12', u'1789', u'CLT', u'PBI'),
#   (u'US', u'2015-04-12', u'1789', u'PHL', u'TPA'),
#   (u'US', u'2015-04-12', u'1789', u'TPA', u'CLT'),
#   (u'US', u'2015-04-12', u'1856', u'PBI', u'CLT'),
#   (u'US', u'2015-04-23', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-04-24', u'1708', u'DFW', u'PHL'),
#   (u'US', u'2015-04-24', u'1708', u'PHL', u'BOS'),
#   (u'US', u'2015-04-24', u'1848', u'PHL', u'DFW'),
#   (u'US', u'2015-04-24', u'1848', u'TPA', u'PHL'),
#   (u'US', u'2015-04-26', u'1732', u'BOS', u'PHL'),
#   (u'US', u'2015-04-26', u'2049', u'PHL', u'PBI'),
#   (u'US', u'2015-04-26', u'555', u'PBI', u'PHL'),
#   (u'US', u'2015-04-26', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-04-27', u'2011', u'PBI', u'PHL'),
#   (u'US', u'2015-04-27', u'2011', u'PHL', u'PBI'),
#   (u'US', u'2015-04-27', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-04-28', u'1866', u'CLT', u'PBI'),
#   (u'US', u'2015-04-28', u'1866', u'PHL', u'CLT'),
#   (u'US', u'2015-04-28', u'1972', u'CLT', u'EWR'),
#   (u'US', u'2015-04-28', u'1972', u'PBI', u'CLT'),
#   (u'US', u'2015-04-28', u'423', u'EWR', u'CLT'),
#   (u'US', u'2015-04-29', u'1725', u'CLT', u'MCO'),
#   (u'US', u'2015-04-29', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-04-29', u'1747', u'IAH', u'CLT'),
#   (u'US', u'2015-04-29', u'657', u'CLT', u'IAH'),
#   (u'US', u'2015-04-29', u'887', u'MCO', u'CLT'),
#   (u'US', u'2015-04-30', u'1855', u'CLT', u'MSP'),
#   (u'US', u'2015-04-30', u'1855', u'MSY', u'CLT'),
#   (u'US', u'2015-04-30', u'1922', u'MSP', u'CLT'),
#   (u'US', u'2015-04-30', u'2047', u'CLT', u'MSY'),
#   (u'US', u'2015-04-30', u'2047', u'PIT', u'CLT'),
#   (u'US', u'2015-05-01', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-05-01', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-05-01', u'1877', u'CLT', u'MIA'),
#   (u'US', u'2015-05-01', u'1973', u'MIA', u'CLT'),
#   (u'US', u'2015-05-01', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-05-02', u'1717', u'CLT', u'FLL'),
#   (u'US', u'2015-05-02', u'858', u'MSY', u'CLT'),
#   (u'US', u'2015-05-03', u'492', u'PHL', u'DFW'),
#   (u'US', u'2015-05-03', u'658', u'CLT', u'LAS'),
#   (u'US', u'2015-05-03', u'658', u'FLL', u'CLT'),
#   (u'US', u'2015-05-03', u'734', u'LAS', u'PHL'),
#   (u'US', u'2015-05-04', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-05-04', u'1789', u'CLT', u'PBI'),
#   (u'US', u'2015-05-04', u'1789', u'DFW', u'PHL'),
#   (u'US', u'2015-05-04', u'1789', u'PHL', u'CLT'),
#   (u'US', u'2015-05-04', u'856', u'PBI', u'CLT'),
#   (u'US', u'2015-05-05', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-05-05', u'1919', u'JFK', u'CLT'),
#   (u'US', u'2015-05-05', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-05-05', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-05-05', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-05-05', u'2047', u'PIT', u'CLT'),
#   (u'US', u'2015-05-06', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-05-06', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-05-06', u'2053', u'MIA', u'CLT'),
#   (u'US', u'2015-05-06', u'2053', u'TPA', u'PHL'),
#   (u'US', u'2015-05-07', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-05-07', u'1919', u'JFK', u'CLT'),
#   (u'US', u'2015-05-07', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-05-07', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-05-07', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-05-07', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-05-08', u'2053', u'CLT', u'TPA'),
#   (u'US', u'2015-05-08', u'2053', u'MIA', u'CLT'),
#   (u'US', u'2015-05-08', u'2053', u'TPA', u'PHL'),
#   (u'US', u'2015-05-08', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-05-08', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-05-09', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-05-09', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-05-10', u'1722', u'PHL', u'BOS'),
#   (u'US', u'2015-05-11', u'1747', u'IAH', u'CLT'),
#   (u'US', u'2015-05-11', u'657', u'CLT', u'IAH'),
#   (u'US', u'2015-05-11', u'657', u'PHL', u'CLT'),
#   (u'US', u'2015-05-11', u'764', u'BOS', u'PHL'),
#   (u'US', u'2015-05-11', u'856', u'CLT', u'DCA'),
#   (u'US', u'2015-05-12', u'1830', u'DCA', u'CLT'),
#   (u'US', u'2015-05-12', u'1841', u'CLT', u'RSW'),
#   (u'US', u'2015-05-12', u'1841', u'MSY', u'CLT'),
#   (u'US', u'2015-05-12', u'2047', u'CLT', u'MSY'),
#   (u'US', u'2015-05-12', u'447', u'CLT', u'DEN'),
#   (u'US', u'2015-05-12', u'447', u'RSW', u'CLT'),
#   (u'US', u'2015-05-13', u'1829', u'BWI', u'CLT'),
#   (u'US', u'2015-05-13', u'1970', u'CLT', u'BWI'),
#   (u'US', u'2015-05-13', u'2066', u'DEN', u'CLT'),
#   (u'US', u'2015-05-14', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-05-14', u'1747', u'IAH', u'CLT'),
#   (u'US', u'2015-05-14', u'401', u'CLT', u'PHL'),
#   (u'US', u'2015-05-14', u'657', u'CLT', u'IAH'),
#   (u'US', u'2015-05-14', u'657', u'PHL', u'CLT'),
#   (u'US', u'2015-05-15', u'1841', u'CLT', u'RSW'),
#   (u'US', u'2015-05-15', u'1841', u'MSY', u'CLT'),
#   (u'US', u'2015-05-15', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-05-15', u'2047', u'CLT', u'MSY'),
#   (u'US', u'2015-05-15', u'2047', u'PIT', u'CLT'),
#   (u'US', u'2015-05-15', u'447', u'RSW', u'CLT'),
#   (u'US', u'2015-05-16', u'833', u'MIA', u'CLT'),
#   (u'US', u'2015-05-18', u'1774', u'CLT', u'DTW'),
#   (u'US', u'2015-05-19', u'1828', u'MIA', u'CLT'),
#   (u'US', u'2015-05-19', u'2065', u'CLT', u'IAH'),
#   (u'US', u'2015-05-19', u'2065', u'DTW', u'CLT'),
#   (u'US', u'2015-05-19', u'519', u'IAH', u'CLT'),
#   (u'US', u'2015-05-19', u'731', u'CLT', u'MIA'),
#   (u'US', u'2015-05-20', u'1829', u'BWI', u'CLT'),
#   (u'US', u'2015-05-20', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-05-20', u'1877', u'CLT', u'MIA'),
#   (u'US', u'2015-05-20', u'1970', u'CLT', u'BWI'),
#   (u'US', u'2015-05-20', u'1970', u'MIA', u'CLT'),
#   (u'US', u'2015-05-20', u'820', u'PHX', u'TPA'),
#   (u'US', u'2015-05-20', u'874', u'TPA', u'PHX'),
#   (u'US', u'2015-05-21', u'1758', u'PHL', u'MCO'),
#   (u'US', u'2015-05-21', u'1848', u'TPA', u'PHL'),
#   (u'US', u'2015-05-21', u'648', u'SAN', u'PHL'),
#   (u'US', u'2015-05-21', u'741', u'PHL', u'SAN'),
#   (u'US', u'2015-05-21', u'768', u'MCO', u'PHL'),
#   (u'US', u'2015-05-22', u'1953', u'PHL', u'MIA'),
#   (u'US', u'2015-05-23', u'1890', u'MIA', u'PHL'),
#   (u'US', u'2015-05-23', u'1890', u'PHL', u'CLT'),
#   (u'US', u'2015-05-23', u'522', u'CLT', u'PHL'),
#   (u'US', u'2015-05-23', u'522', u'PHL', u'PBI'),
#   (u'US', u'2015-05-24', u'1749', u'PBI', u'CLT'),
#   (u'US', u'2015-05-26', u'1828', u'MIA', u'CLT'),
#   (u'US', u'2015-05-26', u'731', u'CLT', u'MIA'),
#   (u'US', u'2015-05-27', u'1798', u'MSY', u'CLT'),
#   (u'US', u'2015-05-27', u'2045', u'CLT', u'MSY'),
#   (u'US', u'2015-05-27', u'856', u'CLT', u'DCA'),
#   (u'US', u'2015-05-28', u'1830', u'CLT', u'JFK'),
#   (u'US', u'2015-05-28', u'1830', u'DCA', u'CLT'),
#   (u'US', u'2015-05-28', u'2069', u'JFK', u'CLT'),
#   (u'US', u'2015-05-29', u'1770', u'CLT', u'ORF'),
#   (u'US', u'2015-05-29', u'1870', u'RSW', u'PHL'),
#   (u'US', u'2015-05-29', u'522', u'CLT', u'PHL'),
#   (u'US', u'2015-05-29', u'659', u'PHL', u'RSW'),
#   (u'US', u'2015-05-29', u'887', u'ORF', u'CLT'),
#   (u'US', u'2015-05-30', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-05-30', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-05-30', u'678', u'SJU', u'PHL'),
#   (u'US', u'2015-05-30', u'770', u'PHL', u'SJU'),
#   (u'US', u'2015-05-31', u'1722', u'PHL', u'BOS'),
#   (u'US', u'2015-05-31', u'678', u'SJU', u'PHL'),
#   (u'US', u'2015-05-31', u'770', u'PHL', u'SJU'),
#   (u'US', u'2015-06-01', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-06-01', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-06-01', u'764', u'BOS', u'PHL'),
#   (u'US', u'2015-06-02', u'1935', u'PHL', u'PBI'),
#   (u'US', u'2015-06-03', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-06-03', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-06-03', u'824', u'PBI', u'PHL'),
#   (u'US', u'2015-06-04', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-06-05', u'1774', u'RSW', u'CLT'),
#   (u'US', u'2015-06-05', u'1805', u'CLT', u'IAH'),
#   (u'US', u'2015-06-05', u'1853', u'CLT', u'RSW'),
#   (u'US', u'2015-06-05', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-06-05', u'2046', u'CLT', u'RSW'),
#   (u'US', u'2015-06-05', u'2081', u'RSW', u'CLT'),
#   (u'US', u'2015-06-06', u'1871', u'CLT', u'TPA'),
#   (u'US', u'2015-06-06', u'803', u'STT', u'CLT'),
#   (u'US', u'2015-06-06', u'804', u'CLT', u'STT'),
#   (u'US', u'2015-06-06', u'804', u'IAH', u'CLT'),
#   (u'US', u'2015-06-07', u'1760', u'BOS', u'CLT'),
#   (u'US', u'2015-06-07', u'1760', u'CLT', u'FLL'),
#   (u'US', u'2015-06-07', u'1980', u'CLT', u'BOS'),
#   (u'US', u'2015-06-07', u'1980', u'TPA', u'CLT'),
#   (u'US', u'2015-06-07', u'447', u'CLT', u'DEN'),
#   (u'US', u'2015-06-07', u'447', u'FLL', u'CLT'),
#   (u'US', u'2015-06-08', u'1749', u'CLT', u'MIA'),
#   (u'US', u'2015-06-08', u'1749', u'MIA', u'PHL'),
#   (u'US', u'2015-06-08', u'2058', u'PHL', u'BOS'),
#   (u'US', u'2015-06-08', u'887', u'DEN', u'CLT'),
#   (u'US', u'2015-06-09', u'555', u'PHL', u'SLC'),
#   (u'US', u'2015-06-09', u'555', u'RSW', u'PHL'),
#   (u'US', u'2015-06-09', u'588', u'SLC', u'PHL'),
#   (u'US', u'2015-06-09', u'659', u'BOS', u'PHL'),
#   (u'US', u'2015-06-09', u'659', u'PHL', u'RSW'),
#   (u'US', u'2015-06-10', u'1883', u'PHL', u'TPA'),
#   (u'US', u'2015-06-11', u'1820', u'CLT', u'RSW'),
#   (u'US', u'2015-06-11', u'1820', u'JFK', u'CLT'),
#   (u'US', u'2015-06-11', u'1960', u'CLT', u'BWI'),
#   (u'US', u'2015-06-11', u'1960', u'TPA', u'CLT'),
#   (u'US', u'2015-06-11', u'2017', u'BWI', u'CLT'),
#   (u'US', u'2015-06-11', u'2017', u'CLT', u'JFK'),
#   (u'US', u'2015-06-12', u'1747', u'CLT', u'PIT'),
#   (u'US', u'2015-06-12', u'1747', u'RDU', u'CLT'),
#   (u'US', u'2015-06-12', u'1832', u'RSW', u'CLT'),
#   (u'US', u'2015-06-12', u'2056', u'CLT', u'RDU'),
#   (u'US', u'2015-06-13', u'1979', u'PHL', u'MIA'),
#   (u'US', u'2015-06-13', u'847', u'PIT', u'PHL'),
#   (u'US', u'2015-06-14', u'1976', u'IAH', u'CLT'),
#   (u'US', u'2015-06-14', u'657', u'CLT', u'IAH'),
#   (u'US', u'2015-06-14', u'657', u'MIA', u'PHL'),
#   (u'US', u'2015-06-14', u'657', u'PHL', u'CLT'),
#   (u'US', u'2015-06-14', u'856', u'CLT', u'DCA'),
#   (u'US', u'2015-06-15', u'1782', u'CLT', u'EWR'),
#   (u'US', u'2015-06-15', u'1782', u'IAH', u'CLT'),
#   (u'US', u'2015-06-15', u'1830', u'CLT', u'JFK'),
#   (u'US', u'2015-06-15', u'1830', u'DCA', u'CLT'),
#   (u'US', u'2015-06-15', u'2069', u'CLT', u'IAH'),
#   (u'US', u'2015-06-15', u'2069', u'JFK', u'CLT'),
#   (u'US', u'2015-06-16', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-06-16', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-06-16', u'1813', u'CLT', u'TPA'),
#   (u'US', u'2015-06-16', u'1813', u'EWR', u'CLT'),
#   (u'US', u'2015-06-16', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-06-16', u'2066', u'TPA', u'CLT'),
#   (u'US', u'2015-06-17', u'1919', u'CLT', u'MIA'),
#   (u'US', u'2015-06-17', u'1961', u'MSY', u'CLT'),
#   (u'US', u'2015-06-18', u'821', u'MIA', u'CLT'),
#   (u'US', u'2015-06-18', u'856', u'CLT', u'DCA'),
#   (u'US', u'2015-06-19', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-06-19', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-06-19', u'1830', u'CLT', u'JFK'),
#   (u'US', u'2015-06-19', u'1830', u'DCA', u'CLT'),
#   (u'US', u'2015-06-19', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-06-19', u'2069', u'JFK', u'CLT'),
#   (u'US', u'2015-06-20', u'1735', u'CLT', u'LAS'),
#   (u'US', u'2015-06-20', u'2039', u'LAS', u'CLT'),
#   (u'US', u'2015-06-20', u'876', u'MSY', u'CLT'),
#   (u'US', u'2015-06-21', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-06-21', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-06-21', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-06-21', u'525', u'CLT', u'FLL'),
#   (u'US', u'2015-06-21', u'873', u'FLL', u'CLT'),
#   (u'US', u'2015-06-22', u'1829', u'CLT', u'TPA'),
#   (u'US', u'2015-06-22', u'1829', u'IAH', u'CLT'),
#   (u'US', u'2015-06-22', u'1829', u'TPA', u'PHX'),
#   (u'US', u'2015-06-22', u'1961', u'MSY', u'CLT'),
#   (u'US', u'2015-06-22', u'2065', u'CLT', u'IAH'),
#   (u'US', u'2015-06-23', u'520', u'PHX', u'BWI'),
#   (u'US', u'2015-06-23', u'575', u'PHX', u'TPA'),
#   (u'US', u'2015-06-23', u'601', u'BWI', u'PHX'),
#   (u'US', u'2015-06-24', u'1760', u'CLT', u'FLL'),
#   (u'US', u'2015-06-24', u'1789', u'PHL', u'CLT'),
#   (u'US', u'2015-06-24', u'1789', u'TPA', u'PHL'),
#   (u'US', u'2015-06-24', u'447', u'CLT', u'DEN'),
#   (u'US', u'2015-06-24', u'447', u'FLL', u'CLT'),
#   (u'US', u'2015-06-25', u'1781', u'CLT', u'MSY'),
#   (u'US', u'2015-06-25', u'1781', u'LGA', u'CLT'),
#   (u'US', u'2015-06-25', u'2066', u'CLT', u'LGA'),
#   (u'US', u'2015-06-25', u'887', u'DEN', u'CLT'),
#   (u'US', u'2015-06-26', u'1789', u'CLT', u'PBI'),
#   (u'US', u'2015-06-26', u'1961', u'MSY', u'CLT'),
#   (u'US', u'2015-06-26', u'856', u'PBI', u'CLT'),
#   (u'US', u'2015-06-27', u'1979', u'PHL', u'MIA'),
#   (u'US', u'2015-06-27', u'824', u'CLT', u'PHL'),
#   (u'US', u'2015-06-28', u'1869', u'CLT', u'PIT'),
#   (u'US', u'2015-06-28', u'821', u'MIA', u'CLT'),
#   (u'US', u'2015-06-29', u'1782', u'IAH', u'CLT'),
#   (u'US', u'2015-06-29', u'1830', u'CLT', u'JFK'),
#   (u'US', u'2015-06-29', u'1866', u'PIT', u'CLT'),
#   (u'US', u'2015-06-29', u'2069', u'CLT', u'IAH'),
#   (u'US', u'2015-06-29', u'2069', u'JFK', u'CLT'),
#   (u'US', u'2015-06-30', u'1749', u'CLT', u'MIA'),
#   (u'US', u'2015-06-30', u'1749', u'EWR', u'CLT'),
#   (u'US', u'2015-06-30', u'1749', u'MIA', u'PHL'),
#   (u'US', u'2015-06-30', u'1984', u'CLT', u'EWR'),
#   (u'US', u'2015-06-30', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-07-01', u'555', u'RSW', u'PHL'),
#   (u'AA', u'2015-07-01', u'659', u'BOS', u'PHL'),
#   (u'AA', u'2015-07-01', u'659', u'PHL', u'RSW'),
#   (u'AA', u'2015-07-02', u'1712', u'PHX', u'PHL'),
#   (u'AA', u'2015-07-02', u'574', u'PHL', u'SFO'),
#   (u'AA', u'2015-07-02', u'574', u'SFO', u'PHX'),
#   (u'AA', u'2015-07-03', u'1739', u'PHL', u'ATL'),
#   (u'AA', u'2015-07-03', u'1823', u'PHL', u'PHX'),
#   (u'AA', u'2015-07-03', u'1864', u'ATL', u'PHL'),
#   (u'AA', u'2015-07-04', u'1752', u'PHX', u'PHL'),
#   (u'AA', u'2015-07-04', u'492', u'PHL', u'DFW'),
#   (u'AA', u'2015-07-05', u'736', u'SJU', u'PHL'),
#   (u'AA', u'2015-07-05', u'773', u'DFW', u'PHL'),
#   (u'AA', u'2015-07-05', u'773', u'PHL', u'SJU'),
#   (u'AA', u'2015-07-06', u'1829', u'CLT', u'TPA'),
#   (u'AA', u'2015-07-06', u'1829', u'IAH', u'CLT'),
#   (u'AA', u'2015-07-06', u'1829', u'TPA', u'PHX'),
#   (u'AA', u'2015-07-06', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-07-06', u'2065', u'PHL', u'CLT'),
#   (u'AA', u'2015-07-06', u'575', u'PHX', u'TPA'),
#   (u'AA', u'2015-07-07', u'1789', u'CLT', u'PBI'),
#   (u'AA', u'2015-07-07', u'1789', u'PHL', u'CLT'),
#   (u'AA', u'2015-07-07', u'1789', u'TPA', u'PHL'),
#   (u'AA', u'2015-07-07', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-07-07', u'856', u'PBI', u'CLT'),
#   (u'AA', u'2015-07-08', u'1782', u'IAH', u'CLT'),
#   (u'AA', u'2015-07-08', u'1830', u'CLT', u'JFK'),
#   (u'AA', u'2015-07-08', u'1830', u'DCA', u'CLT'),
#   (u'AA', u'2015-07-08', u'2069', u'CLT', u'IAH'),
#   (u'AA', u'2015-07-08', u'2069', u'JFK', u'CLT'),
#   (u'AA', u'2015-07-08', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-07-09', u'1749', u'CLT', u'MIA'),
#   (u'AA', u'2015-07-09', u'1749', u'DEN', u'CLT'),
#   (u'AA', u'2015-07-09', u'1749', u'MIA', u'PHL'),
#   (u'AA', u'2015-07-09', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-07-10', u'1883', u'PHL', u'TPA'),
#   (u'AA', u'2015-07-10', u'555', u'RSW', u'PHL'),
#   (u'AA', u'2015-07-10', u'659', u'BOS', u'PHL'),
#   (u'AA', u'2015-07-10', u'659', u'PHL', u'RSW'),
#   (u'AA', u'2015-07-11', u'1711', u'CLT', u'EWR'),
#   (u'AA', u'2015-07-11', u'819', u'TPA', u'CLT'),
#   (u'AA', u'2015-07-12', u'1813', u'CLT', u'TPA'),
#   (u'AA', u'2015-07-12', u'1813', u'EWR', u'CLT'),
#   (u'AA', u'2015-07-12', u'2066', u'TPA', u'CLT'),
#   (u'AA', u'2015-07-14', u'525', u'CLT', u'FLL'),
#   (u'AA', u'2015-07-14', u'673', u'CLT', u'IAH'),
#   (u'AA', u'2015-07-14', u'887', u'FLL', u'CLT'),
#   (u'AA', u'2015-07-15', u'1774', u'RSW', u'CLT'),
#   (u'AA', u'2015-07-15', u'1805', u'CLT', u'IAH'),
#   (u'AA', u'2015-07-15', u'1853', u'CLT', u'RSW'),
#   (u'AA', u'2015-07-15', u'1853', u'IAH', u'CLT'),
#   (u'AA', u'2015-07-15', u'2046', u'CLT', u'RSW'),
#   (u'AA', u'2015-07-15', u'2081', u'RSW', u'CLT'),
#   (u'AA', u'2015-07-16', u'1747', u'RDU', u'CLT'),
#   (u'AA', u'2015-07-16', u'1781', u'CLT', u'MSY'),
#   (u'AA', u'2015-07-16', u'1832', u'CLT', u'EWR'),
#   (u'AA', u'2015-07-16', u'1853', u'IAH', u'CLT'),
#   (u'AA', u'2015-07-16', u'2056', u'CLT', u'RDU'),
#   (u'AA', u'2015-07-16', u'2056', u'EWR', u'CLT'),
#   (u'AA', u'2015-07-17', u'1961', u'MSY', u'CLT'),
#   (u'AA', u'2015-07-17', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-07-18', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-07-18', u'865', u'DCA', u'CLT'),
#   (u'AA', u'2015-07-19', u'1761', u'DCA', u'TPA'),
#   (u'AA', u'2015-07-19', u'1816', u'DCA', u'TPA'),
#   (u'AA', u'2015-07-19', u'1816', u'TPA', u'DCA'),
#   (u'AA', u'2015-07-20', u'1781', u'CLT', u'MSY'),
#   (u'AA', u'2015-07-20', u'1781', u'LGA', u'CLT'),
#   (u'AA', u'2015-07-20', u'1813', u'CLT', u'TPA'),
#   (u'AA', u'2015-07-20', u'2061', u'TPA', u'CLT'),
#   (u'AA', u'2015-07-20', u'2066', u'CLT', u'LGA'),
#   (u'AA', u'2015-07-20', u'2066', u'TPA', u'CLT'),
#   (u'AA', u'2015-07-21', u'1766', u'CLT', u'PHL'),
#   (u'AA', u'2015-07-21', u'1766', u'FLL', u'CLT'),
#   (u'AA', u'2015-07-21', u'1961', u'CLT', u'FLL'),
#   (u'AA', u'2015-07-21', u'1961', u'MSY', u'CLT'),
#   (u'AA', u'2015-07-22', u'1708', u'ORD', u'PHL'),
#   (u'AA', u'2015-07-22', u'1850', u'MCO', u'PHL'),
#   (u'AA', u'2015-07-22', u'1850', u'PHL', u'MCO'),
#   (u'AA', u'2015-07-22', u'1995', u'PHL', u'ORD'),
#   (u'AA', u'2015-07-22', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-07-23', u'1845', u'DEN', u'PHL'),
#   (u'AA', u'2015-07-23', u'1939', u'PHL', u'SEA'),
#   (u'AA', u'2015-07-23', u'669', u'PHL', u'SEA'),
#   (u'AA', u'2015-07-23', u'776', u'SEA', u'PHL'),
#   (u'AA', u'2015-07-24', u'1991', u'PHL', u'ORD'),
#   (u'AA', u'2015-07-24', u'575', u'PHX', u'TPA'),
#   (u'AA', u'2015-07-24', u'685', u'SEA', u'PHL'),
#   (u'AA', u'2015-07-24', u'735', u'LAS', u'PHX'),
#   (u'AA', u'2015-07-24', u'735', u'PHL', u'LAS'),
#   (u'AA', u'2015-07-24', u'758', u'ORD', u'PHL'),
#   (u'AA', u'2015-07-25', u'1789', u'TPA', u'PHL'),
#   (u'AA', u'2015-07-26', u'555', u'PHL', u'SLC'),
#   (u'AA', u'2015-07-26', u'588', u'SLC', u'PHL'),
#   (u'AA', u'2015-07-27', u'1883', u'PHL', u'TPA'),
#   (u'AA', u'2015-07-28', u'1709', u'CLT', u'FLL'),
#   (u'AA', u'2015-07-28', u'1747', u'CLT', u'PIT'),
#   (u'AA', u'2015-07-28', u'1747', u'RDU', u'CLT'),
#   (u'AA', u'2015-07-28', u'1960', u'TPA', u'CLT'),
#   (u'AA', u'2015-07-28', u'1962', u'FLL', u'CLT'),
#   (u'AA', u'2015-07-28', u'2056', u'CLT', u'RDU'),
#   (u'AA', u'2015-07-29', u'1855', u'CLT', u'MSP'),
#   (u'AA', u'2015-07-29', u'1855', u'PBI', u'CLT'),
#   (u'AA', u'2015-07-29', u'1866', u'CLT', u'PBI'),
#   (u'AA', u'2015-07-29', u'1866', u'PIT', u'CLT'),
#   (u'AA', u'2015-07-29', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-07-29', u'1971', u'MSP', u'CLT'),
#   (u'AA', u'2015-07-30', u'1805', u'CLT', u'IAH'),
#   (u'AA', u'2015-07-30', u'876', u'SYR', u'CLT'),
#   (u'AA', u'2015-07-31', u'1774', u'RSW', u'CLT'),
#   (u'AA', u'2015-07-31', u'1853', u'CLT', u'RSW'),
#   (u'AA', u'2015-07-31', u'1853', u'IAH', u'CLT'),
#   (u'AA', u'2015-07-31', u'2046', u'CLT', u'RSW'),
#   (u'AA', u'2015-07-31', u'2081', u'RSW', u'CLT'),
#   (u'AA', u'2015-08-01', u'1940', u'CLT', u'ALB'),
#   (u'AA', u'2015-08-02', u'867', u'ALB', u'CLT'),
#   (u'AA', u'2015-08-03', u'1760', u'BOS', u'CLT'),
#   (u'AA', u'2015-08-03', u'1760', u'CLT', u'FLL'),
#   (u'AA', u'2015-08-03', u'1980', u'CLT', u'BOS'),
#   (u'AA', u'2015-08-03', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-08-03', u'447', u'FLL', u'CLT'),
#   (u'AA', u'2015-08-04', u'1749', u'CLT', u'MIA'),
#   (u'AA', u'2015-08-04', u'1749', u'DEN', u'CLT'),
#   (u'AA', u'2015-08-04', u'1749', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-04', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-08-05', u'1890', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-05', u'824', u'BOS', u'PHL'),
#   (u'AA', u'2015-08-05', u'825', u'PHL', u'MIA'),
#   (u'AA', u'2015-08-06', u'1708', u'ORD', u'PHL'),
#   (u'AA', u'2015-08-06', u'1708', u'PHL', u'BOS'),
#   (u'AA', u'2015-08-06', u'1850', u'MCO', u'PHL'),
#   (u'AA', u'2015-08-06', u'1850', u'PHL', u'MCO'),
#   (u'AA', u'2015-08-06', u'1995', u'PHL', u'ORD'),
#   (u'AA', u'2015-08-07', u'555', u'PHL', u'SLC'),
#   (u'AA', u'2015-08-07', u'555', u'RSW', u'PHL'),
#   (u'AA', u'2015-08-07', u'588', u'SLC', u'PHL'),
#   (u'AA', u'2015-08-07', u'659', u'BOS', u'PHL'),
#   (u'AA', u'2015-08-07', u'659', u'PHL', u'RSW'),
#   (u'AA', u'2015-08-08', u'1953', u'PHL', u'TPA'),
#   (u'AA', u'2015-08-09', u'1760', u'BOS', u'CLT'),
#   (u'AA', u'2015-08-09', u'1760', u'CLT', u'FLL'),
#   (u'AA', u'2015-08-09', u'1980', u'CLT', u'BOS'),
#   (u'AA', u'2015-08-09', u'1980', u'TPA', u'CLT'),
#   (u'AA', u'2015-08-09', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-08-09', u'447', u'FLL', u'CLT'),
#   (u'AA', u'2015-08-10', u'1749', u'CLT', u'MIA'),
#   (u'AA', u'2015-08-10', u'1749', u'DEN', u'CLT'),
#   (u'AA', u'2015-08-10', u'1749', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-10', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-08-11', u'1890', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-11', u'824', u'BOS', u'PHL'),
#   (u'AA', u'2015-08-11', u'825', u'PHL', u'MIA'),
#   (u'AA', u'2015-08-12', u'1782', u'CLT', u'EWR'),
#   (u'AA', u'2015-08-12', u'1782', u'IAH', u'CLT'),
#   (u'AA', u'2015-08-12', u'1789', u'PHL', u'CLT'),
#   (u'AA', u'2015-08-12', u'1850', u'MCO', u'PHL'),
#   (u'AA', u'2015-08-12', u'1850', u'PHL', u'MCO'),
#   (u'AA', u'2015-08-12', u'2069', u'CLT', u'IAH'),
#   (u'AA', u'2015-08-13', u'525', u'CLT', u'FLL'),
#   (u'AA', u'2015-08-13', u'525', u'EWR', u'CLT'),
#   (u'AA', u'2015-08-13', u'887', u'FLL', u'CLT'),
#   (u'AA', u'2015-08-14', u'1760', u'BOS', u'CLT'),
#   (u'AA', u'2015-08-14', u'1760', u'CLT', u'FLL'),
#   (u'AA', u'2015-08-14', u'1980', u'CLT', u'BOS'),
#   (u'AA', u'2015-08-14', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-08-14', u'447', u'FLL', u'CLT'),
#   (u'AA', u'2015-08-15', u'437', u'ORD', u'PHL'),
#   (u'AA', u'2015-08-15', u'437', u'PHX', u'ORD'),
#   (u'AA', u'2015-08-15', u'437', u'SLC', u'PHX'),
#   (u'AA', u'2015-08-15', u'457', u'DEN', u'PHX'),
#   (u'AA', u'2015-08-15', u'457', u'PHX', u'SLC'),
#   (u'AA', u'2015-08-16', u'1850', u'MCO', u'PHL'),
#   (u'AA', u'2015-08-16', u'1850', u'PHL', u'MCO'),
#   (u'AA', u'2015-08-16', u'1994', u'PHL', u'ORD'),
#   (u'AA', u'2015-08-16', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-08-16', u'783', u'ORD', u'PHL'),
#   (u'AA', u'2015-08-17', u'1890', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-17', u'824', u'BOS', u'PHL'),
#   (u'AA', u'2015-08-17', u'825', u'PHL', u'MIA'),
#   (u'AA', u'2015-08-18', u'1939', u'PHL', u'SEA'),
#   (u'AA', u'2015-08-18', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-08-18', u'776', u'SEA', u'PHL'),
#   (u'AA', u'2015-08-19', u'1845', u'DEN', u'PHL'),
#   (u'AA', u'2015-08-19', u'1883', u'PHL', u'TPA'),
#   (u'AA', u'2015-08-20', u'1789', u'CLT', u'PBI'),
#   (u'AA', u'2015-08-20', u'1789', u'PHL', u'CLT'),
#   (u'AA', u'2015-08-20', u'1789', u'TPA', u'PHL'),
#   (u'AA', u'2015-08-20', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-08-20', u'856', u'PBI', u'CLT'),
#   (u'AA', u'2015-08-21', u'1766', u'CLT', u'PHL'),
#   (u'AA', u'2015-08-21', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-08-21', u'840', u'DCA', u'CLT'),
#   (u'AA', u'2015-08-22', u'1845', u'DEN', u'PHL'),
#   (u'AA', u'2015-08-22', u'1953', u'PHL', u'TPA'),
#   (u'AA', u'2015-08-23', u'1749', u'DFW', u'PHL'),
#   (u'AA', u'2015-08-23', u'1848', u'PHL', u'DFW'),
#   (u'AA', u'2015-08-23', u'1848', u'TPA', u'PHL'),
#   (u'AA', u'2015-08-23', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-08-24', u'1845', u'DEN', u'PHL'),
#   (u'AA', u'2015-08-24', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-08-25', u'2044', u'CLT', u'MIA'),
#   (u'AA', u'2015-08-25', u'2044', u'DEN', u'CLT'),
#   (u'AA', u'2015-08-25', u'2058', u'MIA', u'PHL'),
#   (u'AA', u'2015-08-25', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-08-26', u'1883', u'PHL', u'TPA'),
#   (u'AA', u'2015-08-26', u'669', u'BOS', u'PHL'),
#   (u'AA', u'2015-08-27', u'1789', u'CLT', u'PBI'),
#   (u'AA', u'2015-08-27', u'1960', u'CLT', u'BWI'),
#   (u'AA', u'2015-08-27', u'1960', u'TPA', u'CLT'),
#   (u'AA', u'2015-08-27', u'2017', u'BWI', u'CLT'),
#   (u'AA', u'2015-08-27', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-08-27', u'856', u'PBI', u'CLT'),
#   (u'AA', u'2015-08-28', u'1766', u'CLT', u'PHL'),
#   (u'AA', u'2015-08-28', u'580', u'PHL', u'DEN'),
#   (u'AA', u'2015-08-28', u'840', u'DCA', u'CLT'),
#   (u'AA', u'2015-08-29', u'1845', u'DEN', u'PHL'),
#   (u'AA', u'2015-08-29', u'2004', u'PHL', u'DTW'),
#   (u'AA', u'2015-08-30', u'669', u'DTW', u'PHL'),
#   (u'AA', u'2015-08-30', u'669', u'PHL', u'SEA'),
#   (u'AA', u'2015-08-30', u'685', u'SEA', u'PHL'),
#   (u'AA', u'2015-08-31', u'1830', u'CLT', u'JFK'),
#   (u'AA', u'2015-08-31', u'1830', u'PHL', u'CLT'),
#   (u'AA', u'2015-08-31', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-08-31', u'1971', u'IAH', u'CLT'),
#   (u'AA', u'2015-08-31', u'2069', u'CLT', u'IAH'),
#   (u'AA', u'2015-08-31', u'2069', u'JFK', u'CLT'),
#   (u'AA', u'2015-09-01', u'713', u'CLT', u'MSP'),
#   (u'AA', u'2015-09-01', u'713', u'SYR', u'CLT'),
#   (u'AA', u'2015-09-03', u'1774', u'CLT', u'DTW'),
#   (u'AA', u'2015-09-03', u'1802', u'PIT', u'CLT'),
#   (u'AA', u'2015-09-03', u'1815', u'CLT', u'PIT'),
#   (u'AA', u'2015-09-03', u'1815', u'LGA', u'CLT'),
#   (u'AA', u'2015-09-03', u'2060', u'CLT', u'LGA'),
#   (u'AA', u'2015-09-04', u'1774', u'RSW', u'CLT'),
#   (u'AA', u'2015-09-04', u'1814', u'CLT', u'ATL'),
#   (u'AA', u'2015-09-04', u'2046', u'ATL', u'CLT'),
#   (u'AA', u'2015-09-04', u'2046', u'CLT', u'RSW'),
#   (u'AA', u'2015-09-04', u'2065', u'DTW', u'CLT'),
#   (u'AA', u'2015-09-06', u'1869', u'CLT', u'PIT'),
#   (u'AA', u'2015-09-07', u'1719', u'CLT', u'FLL'),
#   (u'AA', u'2015-09-07', u'1719', u'EWR', u'CLT'),
#   (u'AA', u'2015-09-07', u'1805', u'CLT', u'IAH'),
#   (u'AA', u'2015-09-07', u'1805', u'FLL', u'CLT'),
#   (u'AA', u'2015-09-07', u'1832', u'CLT', u'EWR'),
#   (u'AA', u'2015-09-07', u'1925', u'PIT', u'CLT'),
#   (u'AA', u'2015-09-08', u'1747', u'RDU', u'CLT'),
#   (u'AA', u'2015-09-08', u'1774', u'CLT', u'DTW'),
#   (u'AA', u'2015-09-08', u'1853', u'CLT', u'RSW'),
#   (u'AA', u'2015-09-08', u'1853', u'IAH', u'CLT'),
#   (u'AA', u'2015-09-08', u'2056', u'CLT', u'RDU'),
#   (u'AA', u'2015-09-08', u'2056', u'RSW', u'CLT'),
#   (u'AA', u'2015-09-09', u'1829', u'CLT', u'TPA'),
#   (u'AA', u'2015-09-09', u'1829', u'IAH', u'CLT'),
#   (u'AA', u'2015-09-09', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-09-09', u'2065', u'DTW', u'CLT'),
#   (u'AA', u'2015-09-10', u'1769', u'CLT', u'MCI'),
#   (u'AA', u'2015-09-10', u'1769', u'PBI', u'CLT'),
#   (u'AA', u'2015-09-10', u'1789', u'CLT', u'PBI'),
#   (u'AA', u'2015-09-10', u'1789', u'PHL', u'CLT'),
#   (u'AA', u'2015-09-10', u'1789', u'TPA', u'PHL'),
#   (u'AA', u'2015-09-11', u'876', u'MCI', u'CLT'),
#   (u'AA', u'2015-09-13', u'1919', u'CLT', u'MIA'),
#   (u'AA', u'2015-09-14', u'1717', u'CLT', u'FLL'),
#   (u'AA', u'2015-09-14', u'1719', u'CLT', u'FLL'),
#   (u'AA', u'2015-09-14', u'1805', u'FLL', u'CLT'),
#   (u'AA', u'2015-09-14', u'1808', u'CLT', u'TPA'),
#   (u'AA', u'2015-09-14', u'1808', u'TPA', u'CLT'),
#   (u'AA', u'2015-09-14', u'1967', u'MIA', u'CLT'),
#   (u'AA', u'2015-09-15', u'1760', u'CLT', u'FLL'),
#   (u'AA', u'2015-09-15', u'1760', u'PIT', u'CLT'),
#   (u'AA', u'2015-09-15', u'1801', u'CLT', u'PIT'),
#   (u'AA', u'2015-09-15', u'1801', u'FLL', u'CLT'),
#   (u'AA', u'2015-09-15', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-09-15', u'447', u'FLL', u'CLT'),
#   (u'AA', u'2015-09-16', u'1781', u'CLT', u'MSY'),
#   (u'AA', u'2015-09-16', u'1781', u'LGA', u'CLT'),
#   (u'AA', u'2015-09-16', u'2044', u'DEN', u'CLT'),
#   (u'AA', u'2015-09-16', u'2066', u'CLT', u'LGA'),
#   (u'AA', u'2015-09-17', u'1829', u'IAH', u'CLT'),
#   (u'AA', u'2015-09-17', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-09-17', u'885', u'MSY', u'CLT'),
#   (u'AA', u'2015-09-18', u'1919', u'JFK', u'CLT'),
#   (u'AA', u'2015-09-18', u'1960', u'CLT', u'BWI'),
#   (u'AA', u'2015-09-18', u'2017', u'BWI', u'CLT'),
#   (u'AA', u'2015-09-18', u'2017', u'CLT', u'JFK'),
#   (u'AA', u'2015-09-18', u'447', u'CLT', u'DEN'),
#   (u'AA', u'2015-09-19', u'1749', u'CLT', u'MIA'),
#   (u'AA', u'2015-09-19', u'1749', u'DEN', u'CLT'),
#   (u'AA', u'2015-09-19', u'1749', u'MIA', u'PHL'),
#   (u'AA', u'2015-09-19', u'1953', u'PHL', u'TPA'),
#   (u'AA', u'2015-09-20', u'1749', u'DFW', u'PHL'),
#   (u'AA', u'2015-09-20', u'1789', u'TPA', u'PHL'),
#   (u'AA', u'2015-09-20', u'1848', u'PHL', u'DFW'),
#   (u'AA', u'2015-09-21', u'1790', u'FLL', u'PHL'),
#   (u'AA', u'2015-09-21', u'1883', u'PHL', u'TPA'),
#   (u'AA', u'2015-09-21', u'2001', u'PHL', u'FLL'),
#   (u'AA', u'2015-09-22', u'1919', u'CLT', u'MIA'),
#   (u'AA', u'2015-09-22', u'1919', u'JFK', u'CLT'),
#   (u'AA', u'2015-09-22', u'1960', u'CLT', u'BWI'),
#   (u'AA', u'2015-09-22', u'1960', u'TPA', u'CLT'),
#   (u'AA', u'2015-09-22', u'2017', u'BWI', u'CLT'),
#   (u'AA', u'2015-09-22', u'2017', u'CLT', u'JFK'),
#   (u'AA', u'2015-09-23', u'1967', u'MIA', u'CLT'),
#   (u'AA', u'2015-09-23', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-09-24', u'1820', u'CLT', u'RSW'),
#   (u'AA', u'2015-09-24', u'840', u'DCA', u'CLT'),
#   (u'AA', u'2015-09-25', u'1705', u'PHL', u'PIT'),
#   (u'AA', u'2015-09-25', u'1705', u'PIT', u'PHL'),
#   (u'AA', u'2015-09-25', u'1925', u'CLT', u'TPA'),
#   (u'AA', u'2015-09-25', u'1925', u'TPA', u'PHL'),
#   (u'AA', u'2015-09-25', u'1978', u'RSW', u'CLT'),
#   (u'AA', u'2015-09-27', u'417', u'PHL', u'PDX'),
#   (u'AA', u'2015-09-27', u'418', u'PDX', u'PHL'),
#   (u'AA', u'2015-09-28', u'1747', u'CLT', u'PIT'),
#   (u'AA', u'2015-09-28', u'1774', u'RSW', u'CLT'),
#   (u'AA', u'2015-09-28', u'1913', u'PHL', u'TPA'),
#   (u'AA', u'2015-09-28', u'1913', u'TPA', u'CLT'),
#   (u'AA', u'2015-09-28', u'2046', u'CLT', u'RSW'),
#   (u'AA', u'2015-09-29', u'1925', u'CLT', u'TPA'),
#   (u'AA', u'2015-09-29', u'1925', u'PIT', u'CLT'),
#   (u'AA', u'2015-09-29', u'1925', u'TPA', u'PHL'),
#   (u'AA', u'2015-09-30', u'1774', u'RSW', u'CLT'),
#   (u'AA', u'2015-09-30', u'1913', u'PHL', u'TPA'),
#   (u'AA', u'2015-09-30', u'1913', u'TPA', u'CLT'),
#   (u'AA', u'2015-09-30', u'2046', u'CLT', u'RSW'),
#   (u'AA', u'2015-10-01', u'1855', u'CLT', u'MSP'),
#   (u'AA', u'2015-10-01', u'1855', u'PBI', u'CLT'),
#   (u'AA', u'2015-10-01', u'1866', u'CLT', u'PBI'),
#   (u'AA', u'2015-10-01', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-10-01', u'1971', u'MSP', u'CLT'),
#   (u'AA', u'2015-10-02', u'1781', u'CLT', u'MSY'),
#   (u'AA', u'2015-10-02', u'826', u'SYR', u'CLT'),
#   (u'AA', u'2015-10-03', u'821', u'MSY', u'CLT'),
#   (u'AA', u'2015-10-03', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-10-04', u'1812', u'ATL', u'CLT'),
#   (u'AA', u'2015-10-04', u'1812', u'CLT', u'BOS'),
#   (u'AA', u'2015-10-04', u'2041', u'CLT', u'ATL'),
#   (u'AA', u'2015-10-04', u'883', u'DCA', u'CLT'),
#   (u'AA', u'2015-10-05', u'845', u'BOS', u'PHL'),
#   (u'AA', u'2015-10-06', u'1782', u'CLT', u'EWR'),
#   (u'AA', u'2015-10-06', u'1962', u'CLT', u'BWI'),
#   (u'AA', u'2015-10-06', u'1962', u'TPA', u'CLT'),
#   (u'AA', u'2015-10-06', u'539', u'PHL', u'TPA'),
#   (u'AA', u'2015-10-06', u'864', u'BWI', u'CLT'),
#   (u'AA', u'2015-10-07', u'1723', u'BWI', u'CLT'),
#   (u'AA', u'2015-10-07', u'1970', u'CLT', u'BWI'),
#   (u'AA', u'2015-10-07', u'1989', u'CLT', u'RSW'),
#   (u'AA', u'2015-10-07', u'2066', u'RSW', u'CLT'),
#   (u'AA', u'2015-10-07', u'525', u'EWR', u'CLT'),
#   (u'AA', u'2015-10-08', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-10-09', u'883', u'DCA', u'CLT'),
#   (u'AA', u'2015-10-10', u'1749', u'CLT', u'MIA'),
#   (u'AA', u'2015-10-10', u'1749', u'MIA', u'PHL'),
#   (u'AA', u'2015-10-10', u'1877', u'CLT', u'MIA'),
#   (u'AA', u'2015-10-10', u'893', u'MIA', u'CLT'),
#   (u'AA', u'2015-10-11', u'1830', u'CLT', u'JFK'),
#   (u'AA', u'2015-10-11', u'1830', u'PHL', u'CLT'),
#   (u'AA', u'2015-10-11', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-10-11', u'2035', u'IAH', u'CLT'),
#   (u'AA', u'2015-10-11', u'2069', u'CLT', u'IAH'),
#   (u'AA', u'2015-10-11', u'2069', u'JFK', u'CLT'),
#   (u'AA', u'2015-10-12', u'1723', u'CLT', u'FLL'),
#   (u'AA', u'2015-10-12', u'1915', u'IAH', u'CLT'),
#   (u'AA', u'2015-10-12', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-10-12', u'2065', u'SYR', u'CLT'),
#   (u'AA', u'2015-10-13', u'1830', u'CLT', u'JFK'),
#   (u'AA', u'2015-10-13', u'1830', u'FLL', u'CLT'),
#   (u'AA', u'2015-10-13', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-10-13', u'1971', u'IAH', u'CLT'),
#   (u'AA', u'2015-10-13', u'2069', u'CLT', u'IAH'),
#   (u'AA', u'2015-10-13', u'2069', u'JFK', u'CLT'),
#   (u'AA', u'2015-10-14', u'1782', u'RDU', u'CLT'),
#   (u'AA', u'2015-10-14', u'1915', u'CLT', u'RDU'),
#   (u'AA', u'2015-10-14', u'1915', u'IAH', u'CLT'),
#   (u'AA', u'2015-10-14', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-10-14', u'2065', u'SYR', u'CLT'),
#   (u'AA', u'2015-10-16', u'1984', u'CLT', u'EWR'),
#   (u'AA', u'2015-10-16', u'2044', u'CLT', u'MIA'),
#   (u'AA', u'2015-10-16', u'2044', u'EWR', u'CLT'),
#   (u'AA', u'2015-10-16', u'2058', u'MIA', u'PHL'),
#   (u'AA', u'2015-10-16', u'2058', u'PHL', u'BOS'),
#   (u'AA', u'2015-10-17', u'1963', u'BOS', u'CLT'),
#   (u'AA', u'2015-10-17', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-10-18', u'1919', u'CLT', u'MIA'),
#   (u'AA', u'2015-10-18', u'865', u'DCA', u'CLT'),
#   (u'AA', u'2015-10-19', u'1837', u'CLT', u'RSW'),
#   (u'AA', u'2015-10-19', u'1837', u'RSW', u'CLT'),
#   (u'AA', u'2015-10-19', u'1983', u'MIA', u'CLT'),
#   (u'AA', u'2015-10-19', u'2035', u'ATL', u'CLT'),
#   (u'AA', u'2015-10-19', u'2041', u'CLT', u'ATL'),
#   (u'AA', u'2015-10-20', u'1853', u'CLT', u'RSW'),
#   (u'AA', u'2015-10-20', u'2034', u'RSW', u'CLT'),
#   (u'AA', u'2015-10-23', u'1754', u'CLT', u'BDL'),
#   (u'AA', u'2015-10-24', u'1807', u'BDL', u'CLT'),
#   (u'AA', u'2015-10-24', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-10-25', u'1971', u'CLT', u'SYR'),
#   (u'AA', u'2015-10-25', u'865', u'DCA', u'CLT'),
#   (u'AA', u'2015-10-26', u'1919', u'CLT', u'MIA'),
#   (u'AA', u'2015-10-26', u'2065', u'SYR', u'CLT'),
#   (u'AA', u'2015-10-27', u'1781', u'CLT', u'MSY'),
#   (u'AA', u'2015-10-27', u'1781', u'LGA', u'CLT'),
#   (u'AA', u'2015-10-27', u'1983', u'MIA', u'CLT'),
#   (u'AA', u'2015-10-27', u'2066', u'CLT', u'LGA'),
#   (u'AA', u'2015-10-28', u'1915', u'IAH', u'CLT'),
#   (u'AA', u'2015-10-28', u'2065', u'CLT', u'IAH'),
#   (u'AA', u'2015-10-28', u'821', u'MSY', u'CLT'),
#   (u'AA', u'2015-10-28', u'856', u'CLT', u'DCA'),
#   (u'AA', u'2015-10-29', u'2035', u'ATL', u'CLT'),
#   (u'AA', u'2015-10-29', u'2035', u'CLT', u'JAX'),
#   (u'AA', u'2015-10-29', u'2041', u'CLT', u'ATL'),
#   (u'AA', u'2015-10-29', u'840', u'DCA', u'CLT'),
#   (u'AA', u'2015-10-30', u'1769', u'BWI', u'CLT'),
#   (u'AA', u'2015-10-30', u'1769', u'CLT', u'MCI'),
#   (u'AA', u'2015-10-30', u'1866', u'CLT', u'PBI'),
#   (u'AA', u'2015-10-30', u'1866', u'JAX', u'CLT'),
#   ...],
#  'TailNum': u'N123UW'}

# %% [markdown]
# # Counting Late Flights

# %%
total_flights = on_time_dataframe.count()

# Flights that were late leaving...
late_departures = on_time_dataframe.filter(
  on_time_dataframe.DepDelayMinutes > 0
)
total_late_departures = late_departures.count()
print(total_late_departures)

# Flights that were late arriving...
late_arrivals = on_time_dataframe.filter(
  on_time_dataframe.ArrDelayMinutes > 0
)
total_late_arrivals = late_arrivals.count()
print(total_late_arrivals)

# Get the percentage of flights that are late, rounded to 1 decimal place
pct_late = round((total_late_arrivals / (total_flights * 1.0)) * 100, 1)
# Out:
# 2125618
# 2086896

# %% [markdown]
# # Counting Flights with Hero Captains
#
# "Hero Captains" are those that depart late but make up time in the air and arrive on time or early.

# %%
# Flights that left late but made up time to arrive on time...
on_time_heros = on_time_dataframe.filter(
  (on_time_dataframe.DepDelayMinutes > 0)
  &
  (on_time_dataframe.ArrDelayMinutes <= 0)
)
total_on_time_heros = on_time_heros.count()
print(total_on_time_heros)
# Out:
# 606902

# %% [markdown]
# # Printing Our Results

# %%
print("Total flights:   {:,}".format(total_flights))
print("Late departures: {:,}".format(total_late_departures))
print("Late arrivals:   {:,}".format(total_late_arrivals))
print("Recoveries:      {:,}".format(total_on_time_heros))
print("Percentage Late: {}%".format(pct_late))
# Out:
# Total flights:   5,819,079
# Late departures: 2,125,618
# Late arrivals:   2,086,896
# Recoveries:      606,902
# Percentage Late: 35.9%

# %% [markdown]
# # Computing the Average Lateness Per Flights

# %%
# Get the average minutes late departing and arriving
spark.sql("""
SELECT
  ROUND(AVG(DepDelay),1) AS AvgDepDelay,
  ROUND(AVG(ArrDelay),1) AS AvgArrDelay
FROM on_time_performance
"""
).show()
# Out:
# +-----------+-----------+
# |AvgDepDelay|AvgArrDelay|
# +-----------+-----------+
# |        9.4|        4.4|
# +-----------+-----------+

# %% [markdown]
# # Inspecting Late Flights

# %%
# Why are flights late? Lets look at some delayed flights and the delay causes
late_flights = spark.sql("""
SELECT
  ArrDelayMinutes,
  WeatherDelay,
  CarrierDelay,
  NASDelay,
  SecurityDelay,
  LateAircraftDelay
FROM
  on_time_performance
WHERE
  WeatherDelay IS NOT NULL
  OR
  CarrierDelay IS NOT NULL
  OR
  NASDelay IS NOT NULL
  OR
  SecurityDelay IS NOT NULL
  OR
  LateAircraftDelay IS NOT NULL
ORDER BY
  FlightDate
""")
late_flights.sample(False, 0.01).show()
# Out:
# +---------------+------------+------------+--------+-------------+-----------------+
# |ArrDelayMinutes|WeatherDelay|CarrierDelay|NASDelay|SecurityDelay|LateAircraftDelay|
# +---------------+------------+------------+--------+-------------+-----------------+
# |           36.0|         0.0|         0.0|    36.0|          0.0|              0.0|
# |           15.0|         5.0|         0.0|     0.0|          0.0|             10.0|
# |           32.0|         0.0|         8.0|    24.0|          0.0|              0.0|
# |           95.0|        10.0|         0.0|    85.0|          0.0|              0.0|
# |           43.0|         0.0|        43.0|     0.0|          0.0|              0.0|
# |           40.0|         0.0|         6.0|     7.0|          0.0|             27.0|
# |           16.0|         0.0|         8.0|     8.0|          0.0|              0.0|
# |           72.0|         4.0|         0.0|    18.0|          0.0|             50.0|
# |           69.0|         0.0|         0.0|    13.0|          0.0|             56.0|
# |           35.0|         0.0|         0.0|    12.0|          0.0|             23.0|
# |           17.0|         0.0|         8.0|     9.0|          0.0|              0.0|
# |           15.0|         0.0|        15.0|     0.0|          0.0|              0.0|
# |           33.0|         0.0|        33.0|     0.0|          0.0|              0.0|
# |           89.0|         0.0|        82.0|     7.0|          0.0|              0.0|
# |           15.0|         0.0|        15.0|     0.0|          0.0|              0.0|
# |           30.0|         0.0|        29.0|     1.0|          0.0|              0.0|
# |           46.0|         0.0|         6.0|    32.0|          0.0|              8.0|
# |           25.0|         0.0|         8.0|     0.0|          0.0|             17.0|
# |           34.0|         0.0|        30.0|     4.0|          0.0|              0.0|
# |           15.0|         0.0|         0.0|     0.0|          0.0|             15.0|
# +---------------+------------+------------+--------+-------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# # Determining Why Flights Are Late

# %%
# Calculate the percentage contribution to delay for each source
total_delays = spark.sql("""
SELECT
  ROUND(SUM(WeatherDelay)/SUM(ArrDelayMinutes) * 100, 1) AS pct_weather_delay,
  ROUND(SUM(CarrierDelay)/SUM(ArrDelayMinutes) * 100, 1) AS pct_carrier_delay,
  ROUND(SUM(NASDelay)/SUM(ArrDelayMinutes) * 100, 1) AS pct_nas_delay,
  ROUND(SUM(SecurityDelay)/SUM(ArrDelayMinutes) * 100, 1) AS pct_security_delay,
  ROUND(SUM(LateAircraftDelay)/SUM(ArrDelayMinutes) * 100, 1) AS pct_late_aircraft_delay
FROM on_time_performance
""")
total_delays.show()
# Out:
# +-----------------+-----------------+-------------+------------------+-----------------------+
# |pct_weather_delay|pct_carrier_delay|pct_nas_delay|pct_security_delay|pct_late_aircraft_delay|
# +-----------------+-----------------+-------------+------------------+-----------------------+
# |              4.5|             29.2|         20.7|               0.1|                   36.1|
# +-----------------+-----------------+-------------+------------------+-----------------------+

# %% [markdown]
# # Computing a Histogram of Weather Delayed Flights

# %%
# Eyeball the first to define our buckets
weather_delay_histogram = on_time_dataframe\
  .select("WeatherDelay")\
  .rdd\
  .flatMap(lambda x: x)\
  .histogram([1, 5, 10, 15, 30, 60, 120, 240, 480, 720, 24*60.0])
print(weather_delay_histogram)
# Out:
# ([1, 5, 10, 15, 30, 60, 120, 240, 480, 720, 1440.0], [5436, 7668, 6636, 16007, 13569, 9442, 4598, 1136, 152, 72])

# %%
create_hist(weather_delay_histogram)
# Out:
# <Container object of 10 artists>

# %% [markdown]
# # Preparing a Histogram for Visualization by d3.js

# %%
# Transform the data into something easily consumed by d3
def histogram_to_publishable(histogram):
  record = {'key': 1, 'data': []}
  for label, value in zip(histogram[0], histogram[1]):
    record['data'].append(
      {
        'label': label,
        'value': value
      }
    )
  return record

# Recompute the weather histogram with a filter for on-time flights
weather_delay_histogram = on_time_dataframe\
  .filter(
    (on_time_dataframe.WeatherDelay != None)
    &
    (on_time_dataframe.WeatherDelay > 0)
  )\
  .select("WeatherDelay")\
  .rdd\
  .flatMap(lambda x: x)\
  .histogram([0, 15, 30, 60, 120, 240, 480, 720, 24*60.0])
print(weather_delay_histogram)

record = histogram_to_publishable(weather_delay_histogram)
record

# %% [markdown]
# # Building a Classifier Model to Predict Flight Delays
#
# ## Loading Our Data

# %%
from pyspark.sql.types import StringType, IntegerType, FloatType, DoubleType, DateType, TimestampType
from pyspark.sql.types import StructType, StructField
from pyspark.sql.functions import udf

schema = StructType([
  StructField("ArrDelay", DoubleType(), True),     # "ArrDelay":5.0
  StructField("CRSArrTime", TimestampType(), True),    # "CRSArrTime":"2015-12-31T03:20:00.000-08:00"
  StructField("CRSDepTime", TimestampType(), True),    # "CRSDepTime":"2015-12-31T03:05:00.000-08:00"
  StructField("Carrier", StringType(), True),     # "Carrier":"WN"
  StructField("DayOfMonth", IntegerType(), True), # "DayOfMonth":31
  StructField("DayOfWeek", IntegerType(), True),  # "DayOfWeek":4
  StructField("DayOfYear", IntegerType(), True),  # "DayOfYear":365
  StructField("DepDelay", DoubleType(), True),     # "DepDelay":14.0
  StructField("Dest", StringType(), True),        # "Dest":"SAN"
  StructField("Distance", DoubleType(), True),     # "Distance":368.0
  StructField("FlightDate", DateType(), True),    # "FlightDate":"2015-12-30T16:00:00.000-08:00"
  StructField("FlightNum", StringType(), True),   # "FlightNum":"6109"
  StructField("Origin", StringType(), True),      # "Origin":"TUS"
])

features = spark.read.json(
  "../data/simple_flight_delay_features.jsonl.bz2",
  schema=schema
)
features.first()
# Out:
# Row(ArrDelay=13.0, CRSArrTime=datetime.datetime(2015, 1, 1, 10, 10), CRSDepTime=datetime.datetime(2015, 1, 1, 7, 30), Carrier='AA', DayOfMonth=1, DayOfWeek=4, DayOfYear=1, DepDelay=14.0, Dest='DFW', Distance=569.0, FlightDate=datetime.date(2014, 12, 31), FlightNum='1024', Origin='ABQ')

# %% [markdown]
# ## Check Data for Nulls

# %%
#
# Check for nulls in features before using Spark ML
#
null_counts = [(column, features.where(features[column].isNull()).count()) for column in features.columns]
cols_with_nulls = filter(lambda x: x[1] > 0, null_counts)
print(list(cols_with_nulls))
# Out:
# []

# %% [markdown]
# ## Add a Route Column
#
# Demonstrating the addition of a feature to our model...

# %%
#
# Add a Route variable to replace FlightNum
#
from pyspark.sql.functions import lit, concat

features_with_route = features.withColumn(
  'Route',
  concat(
    features.Origin,
    lit('-'),
    features.Dest
  )
)
features_with_route.select("Origin", "Dest", "Route").show(5)
# Out:
# +------+----+-------+
# |Origin|Dest|  Route|
# +------+----+-------+
# |   ABQ| DFW|ABQ-DFW|
# |   ABQ| DFW|ABQ-DFW|
# |   ABQ| DFW|ABQ-DFW|
# |   ATL| DFW|ATL-DFW|
# |   ATL| DFW|ATL-DFW|
# +------+----+-------+
# only showing top 5 rows

# %% [markdown]
# ## Bucketizing ArrDelay into ArrDelayBucket

# %%
#
# Use pysmark.ml.feature.Bucketizer to bucketize ArrDelay
#
from pyspark.ml.feature import Bucketizer

splits = [-float("inf"), -15.0, 0, 30.0, float("inf")]
bucketizer = Bucketizer(
  splits=splits,
  inputCol="ArrDelay",
  outputCol="ArrDelayBucket"
)
ml_bucketized_features = bucketizer.transform(features_with_route)

# Check the buckets out
ml_bucketized_features.select("ArrDelay", "ArrDelayBucket").show()
# Out:
# +--------+--------------+
# |ArrDelay|ArrDelayBucket|
# +--------+--------------+
# |    13.0|           2.0|
# |    17.0|           2.0|
# |    36.0|           3.0|
# |   -21.0|           0.0|
# |   -14.0|           1.0|
# |    16.0|           2.0|
# |    -7.0|           1.0|
# |    13.0|           2.0|
# |    25.0|           2.0|
# |    58.0|           3.0|
# |    14.0|           2.0|
# |     1.0|           2.0|
# |   -29.0|           0.0|
# |   -10.0|           1.0|
# |    -3.0|           1.0|
# |    -8.0|           1.0|
# |    -1.0|           1.0|
# |   -14.0|           1.0|
# |   -16.0|           0.0|
# |    18.0|           2.0|
# +--------+--------------+
# only showing top 20 rows

# %% [markdown]
# ## Indexing Our String Fields into Numeric Fields

# %%
#
# Extract features tools in with pyspark.ml.feature
#
from pyspark.ml.feature import StringIndexer, VectorAssembler

# Turn category fields into categoric feature vectors, then drop intermediate fields
for column in ["Carrier", "DayOfMonth", "DayOfWeek", "DayOfYear",
               "Origin", "Dest", "Route"]:
  string_indexer = StringIndexer(
    inputCol=column,
    outputCol=column + "_index"
  )
  ml_bucketized_features = string_indexer.fit(ml_bucketized_features)\
                                          .transform(ml_bucketized_features)

# Check out the indexes
ml_bucketized_features.show(6)
# Out:
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+-------------+----------------+---------------+---------------+------------+----------+-----------+
# |ArrDelay|          CRSArrTime|          CRSDepTime|Carrier|DayOfMonth|DayOfWeek|DayOfYear|DepDelay|Dest|Distance|FlightDate|FlightNum|Origin|  Route|ArrDelayBucket|Carrier_index|DayOfMonth_index|DayOfWeek_index|DayOfYear_index|Origin_index|Dest_index|Route_index|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+-------------+----------------+---------------+---------------+------------+----------+-----------+
# |    13.0|2015-01-01 10:10:...|2015-01-01 07:30:...|     AA|         1|        4|        1|    14.0| DFW|   569.0|2014-12-31|     1024|   ABQ|ABQ-DFW|           2.0|          2.0|            25.0|            0.0|          320.0|        53.0|       2.0|      938.0|
# |    17.0|2015-01-01 02:15:...|2014-12-31 23:25:...|     AA|         1|        4|        1|    14.0| DFW|   569.0|2014-12-31|     1184|   ABQ|ABQ-DFW|           2.0|          2.0|            25.0|            0.0|          320.0|        53.0|       2.0|      938.0|
# |    36.0|2015-01-01 03:45:...|2015-01-01 01:00:...|     AA|         1|        4|        1|    -2.0| DFW|   569.0|2014-12-31|      336|   ABQ|ABQ-DFW|           3.0|          2.0|            25.0|            0.0|          320.0|        53.0|       2.0|      938.0|
# |   -21.0|2015-01-01 11:30:...|2015-01-01 09:55:...|     AA|         1|        4|        1|    -1.0| DFW|   731.0|2014-12-31|      125|   ATL|ATL-DFW|           0.0|          2.0|            25.0|            0.0|          320.0|         0.0|       2.0|       37.0|
# |   -14.0|2015-01-01 02:25:...|2015-01-01 00:55:...|     AA|         1|        4|        1|    -4.0| DFW|   731.0|2014-12-31|     1455|   ATL|ATL-DFW|           1.0|          2.0|            25.0|            0.0|          320.0|         0.0|       2.0|       37.0|
# |    16.0|2015-01-01 07:15:...|2015-01-01 05:45:...|     AA|         1|        4|        1|    15.0| DFW|   731.0|2014-12-31|     1473|   ATL|ATL-DFW|           2.0|          2.0|            25.0|            0.0|          320.0|         0.0|       2.0|       37.0|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+-------------+----------------+---------------+---------------+------------+----------+-----------+
# only showing top 6 rows

# %% [markdown]
# ## Combining Numeric Fields into a Single Vector

# %%
# Handle continuous, numeric fields by combining them into one feature vector
numeric_columns = ["DepDelay", "Distance"]
index_columns = ["Carrier_index", "DayOfMonth_index",
                   "DayOfWeek_index", "DayOfYear_index", "Origin_index",
                   "Origin_index", "Dest_index", "Route_index"]
vector_assembler = VectorAssembler(
  inputCols=numeric_columns + index_columns,
  outputCol="Features_vec"
)
final_vectorized_features = vector_assembler.transform(ml_bucketized_features)

# Drop the index columns
for column in index_columns:
  final_vectorized_features = final_vectorized_features.drop(column)

# Check out the features
final_vectorized_features.show()
# Out:
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+
# |ArrDelay|          CRSArrTime|          CRSDepTime|Carrier|DayOfMonth|DayOfWeek|DayOfYear|DepDelay|Dest|Distance|FlightDate|FlightNum|Origin|  Route|ArrDelayBucket|        Features_vec|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+
# |    13.0|2015-01-01 10:10:...|2015-01-01 07:30:...|     AA|         1|        4|        1|    14.0| DFW|   569.0|2014-12-31|     1024|   ABQ|ABQ-DFW|           2.0|[14.0,569.0,2.0,2...|
# |    17.0|2015-01-01 02:15:...|2014-12-31 23:25:...|     AA|         1|        4|        1|    14.0| DFW|   569.0|2014-12-31|     1184|   ABQ|ABQ-DFW|           2.0|[14.0,569.0,2.0,2...|
# |    36.0|2015-01-01 03:45:...|2015-01-01 01:00:...|     AA|         1|        4|        1|    -2.0| DFW|   569.0|2014-12-31|      336|   ABQ|ABQ-DFW|           3.0|[-2.0,569.0,2.0,2...|
# |   -21.0|2015-01-01 11:30:...|2015-01-01 09:55:...|     AA|         1|        4|        1|    -1.0| DFW|   731.0|2014-12-31|      125|   ATL|ATL-DFW|           0.0|[-1.0,731.0,2.0,2...|
# |   -14.0|2015-01-01 02:25:...|2015-01-01 00:55:...|     AA|         1|        4|        1|    -4.0| DFW|   731.0|2014-12-31|     1455|   ATL|ATL-DFW|           1.0|[-4.0,731.0,2.0,2...|
# |    16.0|2015-01-01 07:15:...|2015-01-01 05:45:...|     AA|         1|        4|        1|    15.0| DFW|   731.0|2014-12-31|     1473|   ATL|ATL-DFW|           2.0|[15.0,731.0,2.0,2...|
# |    -7.0|2015-01-01 04:15:...|2015-01-01 02:45:...|     AA|         1|        4|        1|    -2.0| DFW|   731.0|2014-12-31|     1513|   ATL|ATL-DFW|           1.0|[-2.0,731.0,2.0,2...|
# |    13.0|2015-01-01 08:50:...|2015-01-01 07:25:...|     AA|         1|        4|        1|     9.0| DFW|   731.0|2014-12-31|      194|   ATL|ATL-DFW|           2.0|[9.0,731.0,2.0,25...|
# |    25.0|2015-01-01 12:30:...|2015-01-01 11:00:...|     AA|         1|        4|        1|    -2.0| DFW|   731.0|2014-12-31|      232|   ATL|ATL-DFW|           2.0|[-2.0,731.0,2.0,2...|
# |    58.0|2015-01-01 13:40:...|2015-01-01 12:15:...|     AA|         1|        4|        1|    14.0| DFW|   731.0|2014-12-31|      276|   ATL|ATL-DFW|           3.0|[14.0,731.0,2.0,2...|
# |    14.0|2015-01-01 05:25:...|2015-01-01 03:55:...|     AA|         1|        4|        1|    15.0| DFW|   731.0|2014-12-31|      314|   ATL|ATL-DFW|           2.0|[15.0,731.0,2.0,2...|
# |     1.0|2015-01-01 10:05:...|2015-01-01 08:40:...|     AA|         1|        4|        1|    -5.0| DFW|   731.0|2014-12-31|      356|   ATL|ATL-DFW|           2.0|[-5.0,731.0,2.0,2...|
# |   -29.0|2015-01-01 02:12:...|2015-01-01 00:15:...|     AA|         1|        4|        1|    -9.0| MIA|   594.0|2014-12-31|     1652|   ATL|ATL-MIA|           0.0|[-9.0,594.0,2.0,2...|
# |   -10.0|2015-01-01 00:52:...|2014-12-31 23:00:...|     AA|         1|        4|        1|    -4.0| MIA|   594.0|2014-12-31|       17|   ATL|ATL-MIA|           1.0|[-4.0,594.0,2.0,2...|
# |    -3.0|2015-01-01 15:02:...|2015-01-01 13:10:...|     AA|         1|        4|        1|    -7.0| MIA|   594.0|2014-12-31|      349|   ATL|ATL-MIA|           1.0|[-7.0,594.0,2.0,2...|
# |    -8.0|2015-01-01 06:35:...|2015-01-01 05:30:...|     AA|         1|        4|        1|    -2.0| DFW|   190.0|2014-12-31|     1023|   AUS|AUS-DFW|           1.0|[-2.0,190.0,2.0,2...|
# |    -1.0|2014-12-31 22:50:...|2014-12-31 21:50:...|     AA|         1|        4|        1|    -2.0| DFW|   190.0|2014-12-31|     1178|   AUS|AUS-DFW|           1.0|[-2.0,190.0,2.0,2...|
# |   -14.0|2015-01-01 01:40:...|2015-01-01 00:30:...|     AA|         1|        4|        1|    -6.0| DFW|   190.0|2014-12-31|     1296|   AUS|AUS-DFW|           1.0|[-6.0,190.0,2.0,2...|
# |   -16.0|2015-01-01 02:15:...|2015-01-01 01:05:...|     AA|         1|        4|        1|    -4.0| DFW|   190.0|2014-12-31|     1356|   AUS|AUS-DFW|           0.0|[-4.0,190.0,2.0,2...|
# |    18.0|2015-01-01 08:55:...|2015-01-01 07:55:...|     AA|         1|        4|        1|     3.0| DFW|   190.0|2014-12-31|     1365|   AUS|AUS-DFW|           2.0|[3.0,190.0,2.0,25...|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Training Our Model in an Experimental Setup

# %%
#
# Cross validate, train and evaluate classifier
#

# Test/train split
training_data, test_data = final_vectorized_features.randomSplit([0.7, 0.3])

# Instantiate and fit random forest classifier
from pyspark.ml.classification import RandomForestClassifier
rfc = RandomForestClassifier(
  featuresCol="Features_vec",
  labelCol="ArrDelayBucket",
  maxBins=4657,
  maxMemoryInMB=1024
)
model = rfc.fit(training_data)

# Evaluate model using test data
predictions = model.transform(test_data)

from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator = MulticlassClassificationEvaluator(labelCol="ArrDelayBucket", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Accuracy = {}".format(accuracy))

# Check a sample
predictions.sample(False, 0.001, 18).orderBy("CRSDepTime").show(6)
# Out:
# Accuracy = 0.5965632172973679
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+--------------------+--------------------+----------+
# |ArrDelay|          CRSArrTime|          CRSDepTime|Carrier|DayOfMonth|DayOfWeek|DayOfYear|DepDelay|Dest|Distance|FlightDate|FlightNum|Origin|  Route|ArrDelayBucket|        Features_vec|       rawPrediction|         probability|prediction|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+--------------------+--------------------+----------+
# |   -11.0|2014-12-31 22:13:...|2014-12-31 21:10:...|     AA|         1|        4|        1|    -3.0| MIA|   192.0|2014-12-31|     1323|   MCO|MCO-MIA|           1.0|[-3.0,192.0,2.0,2...|[3.15496188966384...|[0.15774809448319...|       1.0|
# |    -3.0|2015-01-01 03:40:...|2015-01-01 02:00:...|     AS|         1|        4|        1|    -9.0| OME|   539.0|2014-12-31|      151|   ANC|ANC-OME|           1.0|[-9.0,539.0,9.0,2...|[4.02192166004895...|[0.20109608300244...|       1.0|
# |   -10.0|2015-01-01 13:10:...|2015-01-01 05:25:...|     VX|         1|        4|        1|     0.0| FLL|  2342.0|2014-12-31|      330|   LAX|LAX-FLL|           1.0|[0.0,2342.0,13.0,...|[4.40711487879725...|[0.22035574393986...|       1.0|
# |     3.0|2015-01-01 06:25:...|2015-01-01 05:25:...|     AA|         1|        4|        1|    -1.0| TUL|   237.0|2014-12-31|     1563|   DFW|DFW-TUL|           2.0|[-1.0,237.0,2.0,2...|[2.53084153459117...|[0.12654207672955...|       1.0|
# |   -14.0|2015-01-01 07:52:...|2015-01-01 06:38:...|     OO|         1|        4|        1|    -9.0| BUR|   326.0|2014-12-31|     6400|   SFO|SFO-BUR|           1.0|[-9.0,326.0,3.0,2...|[3.22466860417944...|[0.16123343020897...|       1.0|
# |     3.0|2015-01-01 15:19:...|2015-01-01 10:45:...|     B6|         1|        4|        1|    -2.0| BOS|  1698.0|2014-12-31|     1038|   AUS|AUS-BOS|           2.0|[-2.0,1698.0,7.0,...|[4.78266368992140...|[0.23913318449607...|       1.0|
# +--------+--------------------+--------------------+-------+----------+---------+---------+--------+----+--------+----------+---------+------+-------+--------------+--------------------+--------------------+--------------------+----------+
# only showing top 6 rows
