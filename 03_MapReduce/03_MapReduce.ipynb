# %% [markdown]
# # 3. MapReduce
#
# For this exercise we are going to use MapReduce in local mode, i.e. we won't be running anything on the cluster!
#
# ## 3.1. Use the commands `head`, `cat`, `uniq`, `wc`, `sort`, `find`, `xargs`, `awk` to evaluate the NASA log file:
#
# * Data File:  <https://github.com/scalable-infrastructure/exercise-2018/blob/master/data/nasa/NASA_access_log_Jul95.gz>
# * Which page was called the most?
# * What was the most frequent return code?
# * How many errors occurred? What is the percentage of errors?

# %%
# !pwd
# !gzip -k -d -f  ../data/nasa/NASA_access_log_Jul95.gz
# Out:
# /naslx/projects/pn69si/mnmda001/mnmda001/exercise-students-2018/03_MapReduce

# %%
# !head ../data/nasa/NASA_access_log_Jul95
# Out:
# 199.72.81.55 - - [01/Jul/1995:00:00:01 -0400] "GET /history/apollo/ HTTP/1.0" 200 6245
# unicomp6.unicomp.net - - [01/Jul/1995:00:00:06 -0400] "GET /shuttle/countdown/ HTTP/1.0" 200 3985
# 199.120.110.21 - - [01/Jul/1995:00:00:09 -0400] "GET /shuttle/missions/sts-73/mission-sts-73.html HTTP/1.0" 200 4085
# burger.letters.com - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/countdown/liftoff.html HTTP/1.0" 304 0
# 199.120.110.21 - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0" 200 4179
# burger.letters.com - - [01/Jul/1995:00:00:12 -0400] "GET /images/NASA-logosmall.gif HTTP/1.0" 304 0
# burger.letters.com - - [01/Jul/1995:00:00:12 -0400] "GET /shuttle/countdown/video/livevideo.gif HTTP/1.0" 200 0
# 205.212.115.106 - - [01/Jul/1995:00:00:12 -0400] "GET /shuttle/countdown/countdown.html HTTP/1.0" 200 3985
# d104.aa.net - - [01/Jul/1995:00:00:13 -0400] "GET /shuttle/countdown/ HTTP/1.0" 200 3985
# 129.94.144.152 - - [01/Jul/1995:00:00:13 -0400] "GET / HTTP/1.0" 200 7074

# %% [markdown]
# ## 3.2 Implement a Python version of this Unix Shell script using this script as template! Run the Python script inside an Hadoop Streaming job.
#
# Template: <https://github.com/scalable-infrastructure/scalable-infrastructure.github.io/blob/master/src/map_reduce.py>

# %%
import os
os.environ["HADOOP_HOME"]="/naslx/projects/pn69si/mnmda001/software/hadoop-2.7.5"
os.environ["PATH"]="/naslx/projects/pn69si/mnmda001/software/hadoop-2.7.5/bin:"+os.environ["PATH"]

# %%
# !hadoop jar ${HADOOP_HOME}/share/hadoop/tools/lib/hadoop-streaming-2.7.5.jar -info

# %%
# !head -n 5 | awk  '{print $1}'

# %% [markdown]
# ---
#
# ## 3.3 Run the program Terasort on 1 GB of data - each record that TeraGen generates is 100 Bytes in size:
#
#     hadoop jar ${HADOOP_HOME}/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.5.jar teragen <number_of_records> <output_directory>
#
#     hadoop jar ${HADOOP_HOME}/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.5.jar terasort <input_directory> <output_directory>
#
#     hadoop jar ${HADOOP_HOME}/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.5.jar teravalidate <input_directory> <output_directory>
#
# Measure the runtime for each step and plot the results! ***Use the `/tmp` directory as output directory!***

# %%
# !hadoop jar ${HADOOP_HOME}/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.5.jar teragen 1000 teragen-100MB
# Out:
# 18/04/04 13:22:36 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 18/04/04 13:22:36 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 18/04/04 13:22:39 INFO terasort.TeraSort: Generating 1000 using 1
# 18/04/04 13:22:39 INFO mapreduce.JobSubmitter: number of splits:1
# 18/04/04 13:22:40 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1541502478_0001
# 18/04/04 13:22:41 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 18/04/04 13:22:41 INFO mapreduce.Job: Running job: job_local1541502478_0001
# 18/04/04 13:22:41 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 18/04/04 13:22:41 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 18/04/04 13:22:41 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 18/04/04 13:22:41 INFO mapred.LocalJobRunner: Waiting for map tasks
# 18/04/04 13:22:41 INFO mapred.LocalJobRunner: Starting task: attempt_local1541502478_0001_m_000000_0
# 18/04/04 13:22:41 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 18/04/04 13:22:41 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 18/04/04 13:22:41 INFO mapred.MapTask: Processing split: org.apache.hadoop.examples.terasort.TeraGen$RangeInputFormat$RangeInputSplit@b6bc9b3
# 18/04/04 13:22:42 INFO mapreduce.Job: Job job_local1541502478_0001 running in uber mode : false
# 18/04/04 13:22:42 INFO mapreduce.Job:  map 0% reduce 0%
# 18/04/04 13:22:42 INFO mapred.LocalJobRunner:
# 18/04/04 13:22:42 INFO mapred.Task: Task:attempt_local1541502478_0001_m_000000_0 is done. And is in the process of committing
# 18/04/04 13:22:42 INFO mapred.LocalJobRunner:
# 18/04/04 13:22:42 INFO mapred.Task: Task attempt_local1541502478_0001_m_000000_0 is allowed to commit now
# 18/04/04 13:22:42 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1541502478_0001_m_000000_0' to file:/naslx/projects/pn69si/mnmda001/mnmda001/exercise-students-2018/03_MapReduce/teragen-100MB/_temporary/0/task_local1541502478_0001_m_000000
# 18/04/04 13:22:42 INFO mapred.LocalJobRunner: map
# 18/04/04 13:22:42 INFO mapred.Task: Task 'attempt_local1541502478_0001_m_000000_0' done.
# 18/04/04 13:22:42 INFO mapred.Task: Final Counters for attempt_local1541502478_0001_m_000000_0: Counters: 16
# 	File System Counters
# 		FILE: Number of bytes read=295958
# 		FILE: Number of bytes written=693308
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=1000
# 		Input split bytes=81
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=514850816
# 	org.apache.hadoop.examples.terasort.TeraGen$Counters
# 		CHECKSUM=2173251765740
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=100792
# 18/04/04 13:22:42 INFO mapred.LocalJobRunner: Finishing task: attempt_local1541502478_0001_m_000000_0
# 18/04/04 13:22:42 INFO mapred.LocalJobRunner: map task executor complete.
# 18/04/04 13:22:43 INFO mapreduce.Job:  map 100% reduce 0%
# 18/04/04 13:22:43 INFO mapreduce.Job: Job job_local1541502478_0001 completed successfully
# 18/04/04 13:22:43 INFO mapreduce.Job: Counters: 16
# 	File System Counters
# 		FILE: Number of bytes read=295958
# 		FILE: Number of bytes written=693308
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=1000
# 		Input split bytes=81
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=514850816
# 	org.apache.hadoop.examples.terasort.TeraGen$Counters
# 		CHECKSUM=2173251765740
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=100792

# %%
# !rm -rf teraout-100MB
# !hadoop jar ${HADOOP_HOME}/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.5.jar terasort teragen-100MB /tmp/teraout-100MB-al
# Out:
# 18/04/04 13:30:13 INFO terasort.TeraSort: starting
# 18/04/04 13:30:17 INFO input.FileInputFormat: Total input paths to process : 1
# Spent 555ms computing base-splits.
# Spent 9ms computing TeraScheduler splits.
# Computing input splits took 570ms
# Sampling 1 splits of 1
# Making 1 from 1000 sampled records
# Computing parititions took 619ms
# Spent 1201ms computing partitions.
# 18/04/04 13:30:18 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 18/04/04 13:30:18 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 18/04/04 13:30:20 INFO mapreduce.JobSubmitter: number of splits:1
# 18/04/04 13:30:20 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local737338829_0001
# 18/04/04 13:30:22 INFO mapred.LocalDistributedCacheManager: Creating symlink: /naslx/projects/pn69si/mnmda001/software/hadoop-2.7.5/tmp/1522841421126/_partition.lst <- /naslx/projects/pn69si/mnmda001/mnmda001/exercise-students-2018/03_MapReduce/_partition.lst
# 18/04/04 13:30:22 INFO mapred.LocalDistributedCacheManager: Localized file:/tmp/teraout-100MB-al/_partition.lst as file:/naslx/projects/pn69si/mnmda001/software/hadoop-2.7.5/tmp/1522841421126/_partition.lst
# 18/04/04 13:30:22 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 18/04/04 13:30:22 INFO mapreduce.Job: Running job: job_local737338829_0001
# 18/04/04 13:30:22 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 18/04/04 13:30:22 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 18/04/04 13:30:22 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 18/04/04 13:30:23 INFO mapred.LocalJobRunner: Waiting for map tasks
# 18/04/04 13:30:23 INFO mapred.LocalJobRunner: Starting task: attempt_local737338829_0001_m_000000_0
# 18/04/04 13:30:23 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 18/04/04 13:30:23 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 18/04/04 13:30:23 INFO mapred.MapTask: Processing split: file:/naslx/projects/pn69si/mnmda001/mnmda001/exercise-students-2018/03_MapReduce/teragen-100MB/part-m-00000:0+100000
# 18/04/04 13:30:23 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 18/04/04 13:30:23 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 18/04/04 13:30:23 INFO mapred.MapTask: soft limit at 83886080
# 18/04/04 13:30:23 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 18/04/04 13:30:23 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 18/04/04 13:30:23 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 18/04/04 13:30:23 INFO mapreduce.Job: Job job_local737338829_0001 running in uber mode : false
# 18/04/04 13:30:23 INFO mapreduce.Job:  map 0% reduce 0%
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner:
# 18/04/04 13:30:24 INFO mapred.MapTask: Starting flush of map output
# 18/04/04 13:30:24 INFO mapred.MapTask: Spilling map output
# 18/04/04 13:30:24 INFO mapred.MapTask: bufstart = 0; bufend = 102000; bufvoid = 104857600
# 18/04/04 13:30:24 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26210400(104841600); length = 3997/6553600
# 18/04/04 13:30:24 INFO mapred.MapTask: Finished spill 0
# 18/04/04 13:30:24 INFO mapred.Task: Task:attempt_local737338829_0001_m_000000_0 is done. And is in the process of committing
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: map
# 18/04/04 13:30:24 INFO mapred.Task: Task 'attempt_local737338829_0001_m_000000_0' done.
# 18/04/04 13:30:24 INFO mapred.Task: Final Counters for attempt_local737338829_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=497655
# 		FILE: Number of bytes written=698015
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=1000
# 		Map output bytes=102000
# 		Map output materialized bytes=104006
# 		Input split bytes=173
# 		Combine input records=0
# 		Spilled Records=1000
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=514850816
# 	File Input Format Counters
# 		Bytes Read=100792
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: Finishing task: attempt_local737338829_0001_m_000000_0
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: map task executor complete.
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: Starting task: attempt_local737338829_0001_r_000000_0
# 18/04/04 13:30:24 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 18/04/04 13:30:24 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 18/04/04 13:30:24 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@71d451cb
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=360395552, maxSingleShuffleLimit=90098888, mergeThreshold=237861072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 18/04/04 13:30:24 INFO reduce.EventFetcher: attempt_local737338829_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 18/04/04 13:30:24 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local737338829_0001_m_000000_0 decomp: 104002 len: 104006 to MEMORY
# 18/04/04 13:30:24 INFO reduce.InMemoryMapOutput: Read 104002 bytes from map-output for attempt_local737338829_0001_m_000000_0
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 104002, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->104002
# 18/04/04 13:30:24 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 18/04/04 13:30:24 INFO mapred.Merger: Merging 1 sorted segments
# 18/04/04 13:30:24 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 103989 bytes
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: Merged 1 segments, 104002 bytes to disk to satisfy reduce memory limit
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: Merging 1 files, 104006 bytes from disk
# 18/04/04 13:30:24 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 18/04/04 13:30:24 INFO mapred.Merger: Merging 1 sorted segments
# 18/04/04 13:30:24 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 103989 bytes
# 18/04/04 13:30:24 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 18/04/04 13:30:24 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 18/04/04 13:30:24 INFO mapreduce.Job:  map 100% reduce 0%
# 18/04/04 13:30:25 INFO mapred.Task: Task:attempt_local737338829_0001_r_000000_0 is done. And is in the process of committing
# 18/04/04 13:30:25 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 18/04/04 13:30:25 INFO mapred.Task: Task attempt_local737338829_0001_r_000000_0 is allowed to commit now
# 18/04/04 13:30:25 INFO output.FileOutputCommitter: Saved output of task 'attempt_local737338829_0001_r_000000_0' to file:/tmp/teraout-100MB-al/_temporary/0/task_local737338829_0001_r_000000
# 18/04/04 13:30:25 INFO mapred.LocalJobRunner: reduce > reduce
# 18/04/04 13:30:25 INFO mapred.Task: Task 'attempt_local737338829_0001_r_000000_0' done.
# 18/04/04 13:30:25 INFO mapred.Task: Final Counters for attempt_local737338829_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=705699
# 		FILE: Number of bytes written=902813
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1000
# 		Reduce shuffle bytes=104006
# 		Reduce input records=1000
# 		Reduce output records=1000
# 		Spilled Records=1000
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=514850816
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=100792
# 18/04/04 13:30:25 INFO mapred.LocalJobRunner: Finishing task: attempt_local737338829_0001_r_000000_0
# 18/04/04 13:30:25 INFO mapred.LocalJobRunner: reduce task executor complete.
# 18/04/04 13:30:25 INFO mapreduce.Job:  map 100% reduce 100%
# 18/04/04 13:30:25 INFO mapreduce.Job: Job job_local737338829_0001 completed successfully
# 18/04/04 13:30:25 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=1203354
# 		FILE: Number of bytes written=1600828
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=1000
# 		Map output bytes=102000
# 		Map output materialized bytes=104006
# 		Input split bytes=173
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1000
# 		Reduce shuffle bytes=104006
# 		Reduce input records=1000
# 		Reduce output records=1000
# 		Spilled Records=2000
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=1029701632
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=100792
# 	File Output Format Counters
# 		Bytes Written=100792
# 18/04/04 13:30:25 INFO terasort.TeraSort: done
